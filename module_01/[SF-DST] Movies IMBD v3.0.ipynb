# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from collections import Counter
print(os.listdir("../"))
# Out:
# ['.git', '00_real_ds_github', 'module_00_real_ds_github', 'module_01', 'README.md']

# %%
data = pd.read_csv('data.csv')
data.head(5)
# Out:
#      imdb_id  popularity     budget     revenue                original_title  \
# 0  tt0369610   32.985763  150000000  1513528810                Jurassic World
# 1  tt1392190   28.419936  150000000   378436354            Mad Max: Fury Road
# 2  tt2908446   13.112507  110000000   295238201                     Insurgent
# 3  tt2488496   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4  tt2820852    9.335014  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  \
# 0              The park is open.
# 1             What a Lovely Day.
# 2     One Choice Can Destroy You
# 3  Every generation has a story.
# 4            Vengeance Hits Home
#
#                                             overview  runtime  \
# 0  Twenty-two years after the events of Jurassic ...      124
# 1  An apocalyptic story set in the furthest reach...      120
# 2  Beatrice Prior must confront her inner demons ...      119
# 3  Thirty years after defeating the Galactic Empi...      136
# 4  Deckard Shaw seeks revenge against Dominic Tor...      137
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date  vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...     6/9/2015        5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...    5/13/2015        6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...    3/18/2015        2480
# 3          Lucasfilm|Truenorth Productions|Bad Robot   12/15/2015        5292
# 4  Universal Pictures|Original Film|Media Rights ...     4/1/2015        2947
#
#    vote_average  release_year
# 0           6.5          2015
# 1           7.1          2015
# 2           6.3          2015
# 3           7.5          2015
# 4           7.3          2015

# %%
len(data)
# Out:
# 1890

# %% [markdown]
# # Предобработка датасета

# %%
answer_ls = [] # создадим список с ответами. сюда будем добавлять ответы по мере прохождения теста
# сюда можем вписать создание новых колонок в датасете
# обозначим прибыль как раздать между сборами и бюджетами
data['income'] = data['revenue'] - data['budget']
# переменуем столбец 'release_month' на 'release_date'
data['release_month'] = data['release_date'].apply(lambda date: date.split('/')[0])

# %% [markdown]
# # 1. У какого фильма из списка самый большой бюджет?
# Варианты ответов:
# 1. The Dark Knight Rises (tt1345836)
# 2. Spider-Man 3 (tt0413300)
# 3. Avengers: Age of Ultron (tt2395427)
# 4. The Warrior's Way	(tt1032751)
# 5. Pirates of the Caribbean: On Stranger Tides (tt1298650)

# %%
# тут вводим ваш ответ и добавлем в его список ответов (сейчас для примера стоит "1")
# вариан 1
movie = data.loc[data['budget'] == data['budget'].max()]
display(movie)
# вариант 2
display(data[data['budget'] == max(data['budget']) ])
# Out:
#        imdb_id  popularity     budget   revenue     original_title  \
# 491  tt1032751     0.25054  425000000  11087569  The Warrior's Way
#
#                                                   cast    director  \
# 491  Kate Bosworth|Jang Dong-gun|Geoffrey Rush|Dann...  Sngmoo Lee
#
#                      tagline  \
# 491  Assassin. Hero. Legend.
#
#                                               overview  runtime  \
# 491  An Asian assassin (Dong-gun Jang) is forced to...      100
#
#                                         genres      production_companies  \
# 491  Adventure|Fantasy|Action|Western|Thriller  Boram Entertainment Inc.
#
#     release_date  vote_count  vote_average  release_year     income  \
# 491    12/2/2010          74           6.4          2010 -413912431
#
#     release_month
# 491            12
#        imdb_id  popularity     budget   revenue     original_title  \
# 491  tt1032751     0.25054  425000000  11087569  The Warrior's Way
#
#                                                   cast    director  \
# 491  Kate Bosworth|Jang Dong-gun|Geoffrey Rush|Dann...  Sngmoo Lee
#
#                      tagline  \
# 491  Assassin. Hero. Legend.
#
#                                               overview  runtime  \
# 491  An Asian assassin (Dong-gun Jang) is forced to...      100
#
#                                         genres      production_companies  \
# 491  Adventure|Fantasy|Action|Western|Thriller  Boram Entertainment Inc.
#
#     release_date  vote_count  vote_average  release_year     income  \
# 491    12/2/2010          74           6.4          2010 -413912431
#
#     release_month
# 491            12

# %%
answer_ls.append(4)

# %% [markdown]
# # 2. Какой из фильмов самый длительный (в минутах)
# 1. The Lord of the Rings: The Return of the King	(tt0167260)
# 2. Gods and Generals	(tt0279111)
# 3. King Kong	(tt0360717)
# 4. Pearl Harbor	(tt0213149)
# 5. Alexander	(tt0346491)

# %%
data = pd.read_csv('data.csv')
data[data['runtime']==data['runtime'].max()]
# Out:
#         imdb_id  popularity    budget   revenue     original_title  \
# 1158  tt0279111    0.469518  56000000  12923936  Gods and Generals
#
#                                                    cast           director  \
# 1158  Stephen Lang|Jeff Daniels|Robert Duvall|Kevin ...  Ronald F. Maxwell
#
#                                   tagline  \
# 1158  The nations heart was touched by...
#
#                                                overview  runtime  \
# 1158  The film centers mostly around the personal an...      214
#
#                  genres                production_companies release_date  \
# 1158  Drama|History|War  Turner Pictures|Antietam Filmworks    2/21/2003
#
#       vote_count  vote_average  release_year
# 1158          23           5.8          2003

# %%
answer_ls.append(2)

# %% [markdown]
# # 3. Какой из фильмов самый короткий (в минутах)
# Варианты ответов:
#
# 1. Home on the Range	tt0299172
# 2. The Jungle Book 2	tt0283426
# 3. Winnie the Pooh	tt1449283
# 4. Corpse Bride	tt0121164
# 5. Hoodwinked!	tt0443536

# %%
data = pd.read_csv('data.csv')
data[data['runtime']==data['runtime'].min()]
# Out:
#        imdb_id  popularity    budget   revenue   original_title  \
# 769  tt1449283    1.425344  30000000  14460000  Winnie the Pooh
#
#                                                   cast  \
# 769  Jim Cummings|Travis Oates|Jim Cummings|Bud Luc...
#
#                       director   tagline  \
# 769  Stephen Anderson|Don Hall  Oh Pooh.
#
#                                               overview  runtime  \
# 769  During an ordinary day in Hundred Acre Wood, W...       63
#
#                genres                               production_companies  \
# 769  Animation|Family  Walt Disney Pictures|Walt Disney Animation Stu...
#
#     release_date  vote_count  vote_average  release_year
# 769    4/13/2011         174           6.8          2011

# %%
answer_ls.append(3)

# %% [markdown]
# # 4. Средняя длительность фильма?
#
# Варианты ответов:
# 1. 115
# 2. 110
# 3. 105
# 4. 120
# 5. 100

# %%
round(data['runtime'].mean())
# Out:
# 110

# %%
answer_ls.append(2)

# %% [markdown]
# # 5. Средняя длительность фильма по медиане?
# Варианты ответов:
# 1. 106
# 2. 112
# 3. 101
# 4. 120
# 5. 115

# %%
round(data['runtime'].median())
# Out:
# 106

# %%
answer_ls.append(1)

# %% [markdown]
# # 6. Какой самый прибыльный фильм?
# Варианты ответов:
# 1. The Avengers	tt0848228
# 2. Minions	tt2293640
# 3. Star Wars: The Force Awakens	tt2488496
# 4. Furious 7	tt2820852
# 5. Avatar	tt0499549

# %%
data[data['revenue']==data['revenue'].max()]
# Out:
#        imdb_id  popularity     budget     revenue original_title  \
# 239  tt0499549    9.432768  237000000  2781505847         Avatar
#
#                                                   cast       director  \
# 239  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...  James Cameron
#
#                          tagline  \
# 239  Enter the World of Pandora.
#
#                                               overview  runtime  \
# 239  In the 22nd century, a paraplegic Marine is di...      162
#
#                                        genres  \
# 239  Action|Adventure|Fantasy|Science Fiction
#
#                                   production_companies release_date  \
# 239  Ingenious Film Partners|Twentieth Century Fox ...   12/10/2009
#
#      vote_count  vote_average  release_year
# 239        8458           7.1          2009

# %%
answer_ls.append(5)

# %% [markdown]
# # 7. Какой фильм самый убыточный?
# Варианты ответов:
# 1. Supernova tt0134983
# 2. The Warrior's Way tt1032751
# 3. Flushed Away	tt0424095
# 4. The Adventures of Pluto Nash	tt0180052
# 5. The Lone Ranger	tt1210819

# %%
data['marjin']=(data['revenue']-data['budget'])
data[data['marjin']==data['marjin'].min()]
# Out:
#        imdb_id  popularity     budget   revenue     original_title  \
# 491  tt1032751     0.25054  425000000  11087569  The Warrior's Way
#
#                                                   cast    director  \
# 491  Kate Bosworth|Jang Dong-gun|Geoffrey Rush|Dann...  Sngmoo Lee
#
#                      tagline  \
# 491  Assassin. Hero. Legend.
#
#                                               overview  runtime  \
# 491  An Asian assassin (Dong-gun Jang) is forced to...      100
#
#                                         genres      production_companies  \
# 491  Adventure|Fantasy|Action|Western|Thriller  Boram Entertainment Inc.
#
#     release_date  vote_count  vote_average  release_year     marjin
# 491    12/2/2010          74           6.4          2010 -413912431

# %%
answer_ls.append(2)

# %% [markdown]
# # 8. Сколько всего фильмов в прибыли?
# Варианты ответов:
# 1. 1478
# 2. 1520
# 3. 1241
# 4. 1135
# 5. 1398

# %%
data['marjin']=(data['revenue']-data['budget'])
data[data['marjin']>0].count()
# Out:
# imdb_id                 1478
# popularity              1478
# budget                  1478
# revenue                 1478
# original_title          1478
# cast                    1478
# director                1478
# tagline                 1478
# overview                1478
# runtime                 1478
# genres                  1478
# production_companies    1478
# release_date            1478
# vote_count              1478
# vote_average            1478
# release_year            1478
# marjin                  1478
# dtype: int64

# %%
answer_ls.append(1)

# %% [markdown]
# # 9. Самый прибыльный фильм в 2008 году?
# Варианты ответов:
# 1. Madagascar: Escape 2 Africa	tt0479952
# 2. Iron Man	tt0371746
# 3. Kung Fu Panda	tt0441773
# 4. The Dark Knight	tt0468569
# 5. Mamma Mia!	tt0795421

# %%
data1=data[(data['release_year']==2008)]
data1[data1['revenue']==data1['revenue'].max()]
# Out:
#        imdb_id  popularity     budget     revenue   original_title  \
# 600  tt0468569    8.466668  185000000  1001921825  The Dark Knight
#
#                                                   cast           director  \
# 600  Christian Bale|Michael Caine|Heath Ledger|Aaro...  Christopher Nolan
#
#              tagline                                           overview  \
# 600  Why So Serious?  Batman raises the stakes in his war on crime. ...
#
#      runtime                       genres  \
# 600      152  Drama|Action|Crime|Thriller
#
#                                   production_companies release_date  \
# 600  DC Comics|Legendary Pictures|Warner Bros.|Syncopy    7/16/2008
#
#      vote_count  vote_average  release_year     marjin
# 600        8432           8.1          2008  816921825

# %%
answer_ls.append(4)

# %% [markdown]
# # 10. Самый убыточный фильм за период с 2012 по 2014 (включительно)?
# Варианты ответов:
# 1. Winter's Tale	tt1837709
# 2. Stolen	tt1656186
# 3. Broken City	tt1235522
# 4. Upside Down	tt1374992
# 5. The Lone Ranger	tt1210819

# %%
data['marjin']=(data['revenue']-data['budget'])
data1=data[(data['release_year']>=2012)&(data['release_year']<=2014)]
data1[data1['marjin']==data1['marjin'].min()]
# Out:
#         imdb_id  popularity     budget   revenue   original_title  \
# 1246  tt1210819     1.21451  255000000  89289910  The Lone Ranger
#
#                                                    cast        director  \
# 1246  Johnny Depp|Armie Hammer|William Fichtner|Hele...  Gore Verbinski
#
#                       tagline  \
# 1246  Never Take Off the Mask
#
#                                                overview  runtime  \
# 1246  The Texas Rangers chase down a gang of outlaws...      149
#
#                         genres  \
# 1246  Action|Adventure|Western
#
#                                    production_companies release_date  \
# 1246  Walt Disney Pictures|Jerry Bruckheimer Films|I...     7/3/2013
#
#       vote_count  vote_average  release_year     marjin
# 1246        1607           6.0          2013 -165710090

# %%
answer_ls.append(5)

# %% [markdown]
# # 11. Какого жанра фильмов больше всего?
# Варианты ответов:
# 1. Action
# 2. Adventure
# 3. Drama
# 4. Comedy
# 5. Thriller

# %%
genres_movies = Counter()
for genre in ['Action', 'Adventure', 'Drama', 'Comedy', 'Thriller']:
    genres_movies[genre] = len(data.loc[data['genres'].str.contains(genre)])
    
display(genres_movies)

genres_movies = pd.Series(genres_movies, index=['Action', 'Adventure', 'Drama', 'Comedy', 'Thriller'])
display(genres_movies.idxmax())
# Out:
# Counter({'Action': 583,
#          'Adventure': 416,
#          'Drama': 782,
#          'Comedy': 683,
#          'Thriller': 597})
# 'Drama'

# %%
answer_ls.append(3)

# %% [markdown]
# # 12. Какого жанра среди прибыльных фильмов больше всего?
# Варианты ответов:
# 1. Drama
# 2. Comedy
# 3. Action
# 4. Thriller
# 5. Adventure

# %%
genres = Counter()
for genre in ['Action', 'Adventure', 'Drama', 'Comedy', 'Thriller']:
    genres[genre] = len(data.loc[(data['genres'].str.contains(genre)) & (data['income'] > 0)])
    
display(genres)

genres = pd.Series(genres, index=['Action', 'Adventure', 'Drama', 'Comedy', 'Thriller'])
display(genres.idxmax())
# Out:
# Counter({'Action': 444,
#          'Adventure': 337,
#          'Drama': 560,
#          'Comedy': 551,
#          'Thriller': 446})
# 'Drama'

# %%
answer_ls.append(1)

# %% [markdown]
# # 13. Кто из режиссеров снял больше всего фильмов?
# Варианты ответов:
# 1. Steven Spielberg
# 2. Ridley Scott
# 3. Steven Soderbergh
# 4. Christopher Nolan
# 5. Clint Eastwood

# %%
data['director'].value_counts()
# Out:
# Steven Soderbergh          13
# Clint Eastwood             12
# Ridley Scott               12
# Shawn Levy                 10
# Steven Spielberg           10
#                            ..
# Gary McKendry               1
# John Gulager                1
# Juan Carlos Fresnadillo     1
# Dewey Nicks                 1
# Gregory Jacobs              1
# Name: director, Length: 958, dtype: int64

# %%
answer_ls.append(3)

# %% [markdown]
# # 14. Кто из режиссеров снял больше всего Прибыльных фильмов?
# Варианты ответов:
# 1. Steven Soderbergh
# 2. Clint Eastwood
# 3. Steven Spielberg
# 4. Ridley Scott
# 5. Christopher Nolan

# %%
data['marjin']=(data['revenue']-data['budget'])
data[data['marjin']>0]['director'].value_counts()
# Out:
# Ridley Scott                   12
# Clint Eastwood                 10
# Steven Soderbergh              10
# Steven Spielberg               10
# Shawn Levy                      9
#                                ..
# Brian Klugman|Lee Sternthal     1
# Michael J. Bassett              1
# John Lasseter|Joe Ranft         1
# Andrew Erwin|Jon Erwin          1
# Stephen Chbosky                 1
# Name: director, Length: 774, dtype: int64

# %%
answer_ls.append(4)

# %% [markdown]
# # 15. Кто из режиссеров принес больше всего прибыли?
# Варианты ответов:
# 1. Steven Spielberg
# 2. Christopher Nolan
# 3. David Yates
# 4. James Cameron
# 5. Peter Jackson

# %%
data_summPruf=data.groupby(['director'])['revenue'].sum()
data_summPruf.sort_values()
# Out:
# director
# Simon Hunter            2033165
# Keanu Reeves            2054941
# Paul Schrader           2062066
# Steven Shainberg        2281089
# David MichÃ´d           2295423
#                         ...
# J.J. Abrams          3579169916
# Michael Bay          3886938960
# David Yates          4154295625
# Christopher Nolan    4167548502
# Peter Jackson        6490593685
# Name: revenue, Length: 958, dtype: int64

# %%
answer_ls.append(5)

# %% [markdown]
# # 16. Какой актер принес больше всего прибыли?
# Варианты ответов:
# 1. Emma Watson
# 2. Johnny Depp
# 3. Michelle Rodriguez
# 4. Orlando Bloom
# 5. Rupert Grint

# %%
artists_list = ['Emma Watson', 'Johnny Depp', 'Michelle Rodriguez', 'Orlando Bloom', 'Rupert Grint']

artists = Counter()
for artist in artists_list:
    artists[artist] = data.loc[data['cast'].str.contains(artist)]['income'].sum()
    
display(artists)

artists = pd.Series(artists, index=artists_list)
display(artists.idxmax())
# Out:
# Counter({'Emma Watson': 6666245597,
#          'Johnny Depp': 4776417000,
#          'Michelle Rodriguez': 4608031235,
#          'Orlando Bloom': 5148578162,
#          'Rupert Grint': 6408638290})
# 'Emma Watson'

# %%
answer_ls.append(1)

# %% [markdown]
# # 17. Какой актер принес меньше всего прибыли в 2012 году?
# Варианты ответов:
# 1. Nicolas Cage
# 2. Danny Huston
# 3. Kirsten Dunst
# 4. Jim Sturgess
# 5. Sami Gayle

# %%
artists_list = ['Nicolas Cage', 'Danny Huston', 'Kirsten Dunst', 'Jim Sturgess', 'Sami Gayle']

artists = Counter()
for artist in artists_list:
    artists[artist] = data.loc[(data['release_year'] == 2012) & (data['cast'].str.contains(artist))]['income'].sum()
    
display(artists)

artists = pd.Series(artists, index=artists_list)
display(artists.idxmin())
# Out:
# Counter({'Nicolas Cage': -32893443,
#          'Danny Huston': -32893443,
#          'Kirsten Dunst': -68109207,
#          'Jim Sturgess': -23410657,
#          'Sami Gayle': -32893443})
# 'Kirsten Dunst'

# %%
answer_ls.append(3)

# %% [markdown]
# # 18. Какой актер снялся в большем количестве высокобюджетных фильмов? (в фильмах где бюджет выше среднего по данной выборке)
# Варианты ответов:
# 1. Tom Cruise
# 2. Mark Wahlberg
# 3. Matt Damon
# 4. Angelina Jolie
# 5. Adam Sandler

# %%
artists_list = ['Tom Cruise', 'Mark Wahlberg', 'Matt Damon', 'Angelina Jolie', 'Adam Sandler']

artists = Counter()
for artist in artists_list:
    artists[artist] = len(data.loc[(data['cast'].str.contains(artist)) & (data['budget'] > data['budget'].mean())])
    
display(artists)

artists = pd.Series(artists, index=artists_list)
display(artists.idxmax())
# Out:
# Counter({'Tom Cruise': 15,
#          'Mark Wahlberg': 14,
#          'Matt Damon': 18,
#          'Angelina Jolie': 16,
#          'Adam Sandler': 17})
# 'Matt Damon'

# %%
answer_ls.append(3)

# %% [markdown]
# # 19. В фильмах какого жанра больше всего снимался Nicolas Cage?
# Варианты ответа:
# 1. Drama
# 2. Action
# 3. Thriller
# 4. Adventure
# 5. Crime

# %%
genres_list = ['Drama', 'Action', 'Thriller', 'Adventure', 'Crime']

genres = Counter()
for genre in genres_list:
    genres[genre] = len(data.loc[(data['genres'].str.contains(genre)) & (data['cast'].str.contains('Nicolas Cage'))])
    
display(genres)

genres = pd.Series(genres, index=genres_list)
display(genres.idxmax())
# Out:
# Counter({'Drama': 12,
#          'Action': 17,
#          'Thriller': 15,
#          'Adventure': 7,
#          'Crime': 10})
# 'Action'

# %%
answer_ls.append(2)

# %% [markdown]
# # 20. Какая студия сняла больше всего фильмов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Paramount Pictures
# 3. Columbia Pictures
# 4. Warner Bros
# 5. Twentieth Century Fox Film Corporation

# %%
temp_list = [i.split('|') for i in data['production_companies']]

def list_unrar(list_of_lists):
    result=[]
    for lst in list_of_lists:
      result.extend(lst)
    return result

temp_counter=Counter(list_unrar(temp_list))
temp_counter.most_common(1)
# Out:
# [('Universal Pictures', 173)]

# %%
answer_ls.append(1)

# %% [markdown]
# # 21. Какая студия сняла больше всего фильмов в 2015 году?
# Варианты ответа:
# 1. Universal Pictures
# 2. Paramount Pictures
# 3. Columbia Pictures
# 4. Warner Bros
# 5. Twentieth Century Fox Film Corporation

# %%
production_companies_list = ['Universal Pictures', 'Paramount Pictures', 'Columbia Pictures', 'Warner Bros', 'Twentieth Century Fox Film Corporation']

production_companies = Counter()
for production_company in production_companies_list:
    production_companies[production_company] = len(data.loc[(data['release_year'] == 2015) & (data['production_companies'].str.contains(production_company))])
    
display(production_companies)

production_companies = pd.Series(production_companies, index=production_companies_list)
display(production_companies.idxmax())
# Out:
# Counter({'Universal Pictures': 11,
#          'Paramount Pictures': 7,
#          'Columbia Pictures': 7,
#          'Warner Bros': 12,
#          'Twentieth Century Fox Film Corporation': 8})
# 'Warner Bros'

# %%
answer_ls.append(4)

# %% [markdown]
# # 22. Какая студия заработала больше всего денег в жанре комедий за все время?
# Варианты ответа:
# 1. Warner Bros
# 2. Universal Pictures (Universal)
# 3. Columbia Pictures
# 4. Paramount Pictures
# 5. Walt Disney

# %%
production_companies_list = ['Universal Pictures', 'Paramount Pictures', 'Columbia Pictures', 'Warner Bros', 'Walt Disney']

production_companies = Counter()
for production_company in production_companies_list:
    production_companies[production_company] = data.loc[(data['genres'].str.match('Comedy')) & (data['production_companies'].str.contains(production_company))]['income'].sum()
    
display(production_companies)

production_companies = pd.Series(production_companies, index=production_companies_list)
display(production_companies.idxmax())
# Out:
# Counter({'Universal Pictures': 5121151527,
#          'Paramount Pictures': 1905015448,
#          'Columbia Pictures': 2956105621,
#          'Warner Bros': 2430748470,
#          'Walt Disney': 1874968657})
# 'Universal Pictures'

# %%
answer_ls.append(2)

# %% [markdown]
# # 23. Какая студия заработала больше всего денег в 2012 году?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Columbia Pictures
# 4. Paramount Pictures
# 5. Lucasfilm

# %%
production_companies_list = ['Universal Pictures', 'Paramount Pictures', 'Columbia Pictures', 'Warner Bros', 'Walt Disney']

production_companies = Counter()
for production_company in production_companies_list:
    production_companies[production_company] = data.loc[(data['release_year'] == 2012) & (data['production_companies'].str.contains(production_company))]['income'].sum()
    
display(production_companies)

production_companies = pd.Series(production_companies, index=production_companies_list)
display(production_companies.idxmax())
# Out:
# Counter({'Universal Pictures': 1981011579,
#          'Paramount Pictures': 410726715,
#          'Columbia Pictures': 2501406608,
#          'Warner Bros': 1258020056,
#          'Walt Disney': 726836264})
# 'Columbia Pictures'

# %%
answer_ls.append(3)

# %% [markdown]
# # 24. Самый убыточный фильм от Paramount Pictures
# Варианты ответа:
#
# 1. K-19: The Widowmaker tt0267626
# 2. Next tt0435705
# 3. Twisted tt0315297
# 4. The Love Guru tt0811138
# 5. The Fighter tt0964517

# %%
max_profit = data.revenue - data.budget
df_profit = max_profit.reset_index()
df_profit.columns = ['index_film', 'profit']
lesion = data.loc[df_profit[data.production_companies.str.contains('Paramount Pictures')].profit.idxmin()].original_title
print(lesion)
# Out:
# K-19: The Widowmaker

# %%
answer_ls.append(1)

# %% [markdown]
# # 25. Какой Самый прибыльный год (заработали больше всего)?
# Варианты ответа:
# 1. 2014
# 2. 2008
# 3. 2012
# 4. 2002
# 5. 2015

# %%
years_list = [2014, 2008, 2012, 2002, 2015]

years = Counter()
for year in years_list:
    years[year] = data.loc[(data['release_year'] == year)]['income'].sum()
    
display(years)

years = pd.Series(years, index=years_list)
display(years.idxmax())
# Out:
# Counter({2014: 16397812953,
#          2008: 11663881990,
#          2012: 16077001687,
#          2002: 9002361487,
#          2015: 18668572378})
# 2015

# %%
answer_ls.append(5)

# %% [markdown]
# # 26. Какой Самый прибыльный год для студии Warner Bros?
# Варианты ответа:
# 1. 2014
# 2. 2008
# 3. 2012
# 4. 2010
# 5. 2015

# %%
years_list = [2014, 2008, 2012, 2010, 2015]

years = Counter()
for year in years_list:
    years[year] = data.loc[(data['release_year'] == year) & (data['production_companies'].str.contains('Warner Bros'))]['income'].sum()
    
display(years)

years = pd.Series(years, index=years_list)
display(years.idxmax())
# Out:
# Counter({2014: 2295464519,
#          2008: 2134595031,
#          2012: 1258020056,
#          2010: 1974712985,
#          2015: 870368348})
# 2014

# %%
answer_ls.append(1)

# %% [markdown]
# # 27. В каком месяце за все годы суммарно вышло больше всего фильмов?
# Варианты ответа:
# 1. Январь
# 2. Июнь
# 3. Декабрь
# 4. Сентябрь
# 5. Май

# %%
month_list = {1: 'Январь', 6: 'Июнь', 12: 'Декабрь', 9: 'Сентябрь', 5: 'Май'}

month_counter = Counter()
for month in month_list:
    month_counter[month] = len(data.loc[data['release_month'] == str(month)])
    
display(month_counter)

month_counter = pd.Series(month_counter, index=month_list)
print(month_list[month_counter.idxmax()])
# Out:
# Counter({1: 110, 6: 147, 12: 191, 9: 227, 5: 140})
# Сентябрь

# %%
answer_ls.append(4)

# %% [markdown]
# # 28. Сколько суммарно вышло фильмов летом? (за июнь, июль, август)
# Варианты ответа:
# 1. 345
# 2. 450
# 3. 478
# 4. 523
# 5. 381

# %%
month_list = ['6', '7', '8']

movies_list = data['release_month'].isin(month_list).sum()
print(movies_list)
# Out:
# 450

# %%
answer_ls.append(2)

# %% [markdown]
# # 29. Какой режисер выпускает (суммарно по годам) больше всего фильмов зимой?
# Варианты ответов:
# 1. Steven Soderbergh
# 2. Christopher Nolan
# 3. Clint Eastwood
# 4. Ridley Scott
# 5. Peter Jackson

# %%
directors_list = ['Steven Soderbergh', 'Clint Eastwood', 'Ridley Scott', 'Christopher Nolan', 'Peter Jackson']

directors = Counter()
for director in directors_list:
    directors[director] = len(data.loc[(data['director'].str.match(director)) & (data['release_month'].isin(['12', '1', '2']))])
    
display(directors)

directors = pd.Series(directors, index=directors_list)
display(directors.idxmax())
# Out:
# Counter({'Steven Soderbergh': 6,
#          'Clint Eastwood': 6,
#          'Ridley Scott': 3,
#          'Christopher Nolan': 0,
#          'Peter Jackson': 7})
# 'Peter Jackson'

# %%
answer_ls.append(5)

# %% [markdown]
# # 30. Какой месяц чаще всего по годам самый прибыльный?
# Варианты ответа:
# 1. Январь
# 2. Июнь
# 3. Декабрь
# 4. Сентябрь
# 5. Май

# %%
month_list = {'1': 'Январь', '6': 'Июнь', '12': 'Декабрь', '9': 'Сентябрь', '5': 'Май'}


income_df = data.groupby(['release_year', 'release_month'])['income'].sum().reset_index()


income_df = income_df.loc[(income_df['release_month'].isin(month_list))]

years_list = income_df['release_year'].unique()


month_counter = Counter()
for year in years_list:

    yearly_income_df = income_df.loc[(income_df['release_year'] == year)]
   
    best_month_df = yearly_income_df.loc[yearly_income_df['income'] == yearly_income_df['income'].max()].reset_index()
    month = best_month_df.iloc[0]['release_month']
    if month not in month_counter:
        month_counter[month] = 0
    month_counter[month] += 1
    
best_month = max(month_counter)
print(month_list[best_month])
# Out:
# Июнь

# %%
answer_ls.append(2)

# %% [markdown]
# # 31. Названия фильмов какой студии в среднем самые длинные по количеству символов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Jim Henson Company, The
# 4. Paramount Pictures
# 5. Four By Two Productions

# %%
data['movie_title_chars_count'] = data['original_title'].apply(lambda title: len(title))

display(data)

production_companies_list = ['Universal Pictures', 'Paramount Pictures', 'Jim Henson Company, The', 'Warner Bros', 'Four By Two Productions']

production_companies = Counter()
for production_company in production_companies_list:
    production_companies[production_company] = data.loc[(data['production_companies'].str.contains(production_company, regex=False))]['movie_title_chars_count'].mean()
    
display(production_companies)

production_companies = pd.Series(production_companies, index=production_companies_list)
display(production_companies.idxmax())
# Out:
#         imdb_id  popularity     budget     revenue  \
# 0     tt0369610   32.985763  150000000  1513528810
# 1     tt1392190   28.419936  150000000   378436354
# 2     tt2908446   13.112507  110000000   295238201
# 3     tt2488496   11.173104  200000000  2068178225
# 4     tt2820852    9.335014  190000000  1506249360
# ...         ...         ...        ...         ...
# 1885  tt0120903    0.182246   75000000   157299717
# 1886  tt0192255    0.123920   22000000    13555988
# 1887  tt0131704    0.104908   76000000    35134820
# 1888  tt0162983    0.031018   40000000    36037909
# 1889  tt0163676    0.015997   15000000     5217498
#
#                             original_title  \
# 0                           Jurassic World
# 1                       Mad Max: Fury Road
# 2                                Insurgent
# 3             Star Wars: The Force Awakens
# 4                                Furious 7
# ...                                    ...
# 1885                                 X-Men
# 1886                    The Little Vampire
# 1887  The Adventures of Rocky & Bullwinkle
# 1888                            Hanging Up
# 1889                          The In Crowd
#
#                                                    cast          director  \
# 0     Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1     Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2     Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3     Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4     Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
# ...                                                 ...               ...
# 1885  Patrick Stewart|Hugh Jackman|Ian McKellen|Hall...      Bryan Singer
# 1886  Richard E. Grant|Jonathan Lipnicki|Jim Carter|...          Uli Edel
# 1887  Rene Russo|Jason Alexander|Piper Perabo|Randy ...       Des McAnuff
# 1888  Meg Ryan|Diane Keaton|Lisa Kudrow|Walter Matth...      Diane Keaton
# 1889  Susan Ward|Lori Heuring|Matthew Settle|Nathan ...      Mary Lambert
#
#                                                 tagline  \
# 0                                     The park is open.
# 1                                    What a Lovely Day.
# 2                            One Choice Can Destroy You
# 3                         Every generation has a story.
# 4                                   Vengeance Hits Home
# ...                                                 ...
# 1885                                   Evolution Begins
# 1886  They're not just best friends, they're blood b...
# 1887            This summer it's not the same old bull.
# 1888                   Every family has a few hang-ups.
# 1889                       What would you do to get in?
#
#                                                overview  runtime  \
# 0     Twenty-two years after the events of Jurassic ...      124
# 1     An apocalyptic story set in the furthest reach...      120
# 2     Beatrice Prior must confront her inner demons ...      119
# 3     Thirty years after defeating the Galactic Empi...      136
# 4     Deckard Shaw seeks revenge against Dominic Tor...      137
# ...                                                 ...      ...
# 1885  Two mutants, Rogue and Wolverine, come to a pr...      104
# 1886  Based on the popular books, the story tells of...       95
# 1887  Rocky and Bullwinkle have been living off the ...       88
# 1888  A trio of sisters bond over their ambivalence ...       94
# 1889  A mentally disturbed young woman takes a job a...      105
#
#                                          genres  \
# 0     Action|Adventure|Science Fiction|Thriller
# 1     Action|Adventure|Science Fiction|Thriller
# 2            Adventure|Science Fiction|Thriller
# 3      Action|Adventure|Science Fiction|Fantasy
# 4                         Action|Crime|Thriller
# ...                                         ...
# 1885           Adventure|Action|Science Fiction
# 1886                      Horror|Family|Foreign
# 1887   Adventure|Animation|Action|Comedy|Family
# 1888                               Comedy|Drama
# 1889                                   Thriller
#
#                                    production_companies release_date  \
# 0     Universal Studios|Amblin Entertainment|Legenda...     6/9/2015
# 1     Village Roadshow Pictures|Kennedy Miller Produ...    5/13/2015
# 2     Summit Entertainment|Mandeville Films|Red Wago...    3/18/2015
# 3             Lucasfilm|Truenorth Productions|Bad Robot   12/15/2015
# 4     Universal Pictures|Original Film|Media Rights ...     4/1/2015
# ...                                                 ...          ...
# 1885  Twentieth Century Fox Film Corporation|Donners...    7/13/2000
# 1886                                    New Line Cinema   10/27/2000
# 1887  Universal Pictures|Capella International|KC Me...    6/30/2000
# 1888  Laurence Mark Productions|Columbia Pictures Co...    2/16/2000
# 1889                              Warner Bros. Pictures    7/19/2000
#
#       vote_count  vote_average  release_year      marjin      income  \
# 0           5562           6.5          2015  1363528810  1363528810
# 1           6185           7.1          2015   228436354   228436354
# 2           2480           6.3          2015   185238201   185238201
# 3           5292           7.5          2015  1868178225  1868178225
# 4           2947           7.3          2015  1316249360  1316249360
# ...          ...           ...           ...         ...         ...
# 1885        2766           6.6          2000    82299717    82299717
# 1886          42           6.4          2000    -8444012    -8444012
# 1887          35           4.0          2000   -40865180   -40865180
# 1888          21           5.2          2000    -3962091    -3962091
# 1889          12           5.2          2000    -9782502    -9782502
#
#      release_month  movie_title_chars_count
# 0                6                       14
# 1                5                       18
# 2                3                        9
# 3               12                       28
# 4                4                        9
# ...            ...                      ...
# 1885             7                        5
# 1886            10                       18
# 1887             6                       36
# 1888             2                       10
# 1889             7                       12
#
# [1890 rows x 20 columns]
# Counter({'Universal Pictures': 14.731428571428571,
#          'Paramount Pictures': 17.0327868852459,
#          'Jim Henson Company, The': 59.0,
#          'Warner Bros': 15.251366120218579,
#          'Four By Two Productions': 83.0})
# 'Four By Two Productions'

# %%
answer_ls.append(5)

# %% [markdown]
# # 32. Названия фильмов какой студии в среднем самые длинные по количеству слов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Jim Henson Company, The
# 4. Paramount Pictures
# 5. Four By Two Productions

# %%
def split_title(title):
    words = title.split(' ')
    return len(words)


data['movie_title_words_count'] = data['original_title'].apply(split_title)
display(data)

production_companies_list = ['Universal Pictures', 'Paramount Pictures', 'Jim Henson Company, The', 'Warner Bros', 'Four By Two Productions']

production_companies = Counter()
for production_company in production_companies_list:
    production_companies[production_company] = data.loc[(data['production_companies'].str.contains(production_company, regex=False))]['movie_title_words_count'].mean()
    
display(production_companies)

production_companies = pd.Series(production_companies, index=production_companies_list)
display(production_companies.idxmax())
# Out:
#         imdb_id  popularity     budget     revenue  \
# 0     tt0369610   32.985763  150000000  1513528810
# 1     tt1392190   28.419936  150000000   378436354
# 2     tt2908446   13.112507  110000000   295238201
# 3     tt2488496   11.173104  200000000  2068178225
# 4     tt2820852    9.335014  190000000  1506249360
# ...         ...         ...        ...         ...
# 1885  tt0120903    0.182246   75000000   157299717
# 1886  tt0192255    0.123920   22000000    13555988
# 1887  tt0131704    0.104908   76000000    35134820
# 1888  tt0162983    0.031018   40000000    36037909
# 1889  tt0163676    0.015997   15000000     5217498
#
#                             original_title  \
# 0                           Jurassic World
# 1                       Mad Max: Fury Road
# 2                                Insurgent
# 3             Star Wars: The Force Awakens
# 4                                Furious 7
# ...                                    ...
# 1885                                 X-Men
# 1886                    The Little Vampire
# 1887  The Adventures of Rocky & Bullwinkle
# 1888                            Hanging Up
# 1889                          The In Crowd
#
#                                                    cast          director  \
# 0     Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1     Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2     Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3     Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4     Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
# ...                                                 ...               ...
# 1885  Patrick Stewart|Hugh Jackman|Ian McKellen|Hall...      Bryan Singer
# 1886  Richard E. Grant|Jonathan Lipnicki|Jim Carter|...          Uli Edel
# 1887  Rene Russo|Jason Alexander|Piper Perabo|Randy ...       Des McAnuff
# 1888  Meg Ryan|Diane Keaton|Lisa Kudrow|Walter Matth...      Diane Keaton
# 1889  Susan Ward|Lori Heuring|Matthew Settle|Nathan ...      Mary Lambert
#
#                                                 tagline  \
# 0                                     The park is open.
# 1                                    What a Lovely Day.
# 2                            One Choice Can Destroy You
# 3                         Every generation has a story.
# 4                                   Vengeance Hits Home
# ...                                                 ...
# 1885                                   Evolution Begins
# 1886  They're not just best friends, they're blood b...
# 1887            This summer it's not the same old bull.
# 1888                   Every family has a few hang-ups.
# 1889                       What would you do to get in?
#
#                                                overview  runtime  ...  \
# 0     Twenty-two years after the events of Jurassic ...      124  ...
# 1     An apocalyptic story set in the furthest reach...      120  ...
# 2     Beatrice Prior must confront her inner demons ...      119  ...
# 3     Thirty years after defeating the Galactic Empi...      136  ...
# 4     Deckard Shaw seeks revenge against Dominic Tor...      137  ...
# ...                                                 ...      ...  ...
# 1885  Two mutants, Rogue and Wolverine, come to a pr...      104  ...
# 1886  Based on the popular books, the story tells of...       95  ...
# 1887  Rocky and Bullwinkle have been living off the ...       88  ...
# 1888  A trio of sisters bond over their ambivalence ...       94  ...
# 1889  A mentally disturbed young woman takes a job a...      105  ...
#
#                                    production_companies release_date  \
# 0     Universal Studios|Amblin Entertainment|Legenda...     6/9/2015
# 1     Village Roadshow Pictures|Kennedy Miller Produ...    5/13/2015
# 2     Summit Entertainment|Mandeville Films|Red Wago...    3/18/2015
# 3             Lucasfilm|Truenorth Productions|Bad Robot   12/15/2015
# 4     Universal Pictures|Original Film|Media Rights ...     4/1/2015
# ...                                                 ...          ...
# 1885  Twentieth Century Fox Film Corporation|Donners...    7/13/2000
# 1886                                    New Line Cinema   10/27/2000
# 1887  Universal Pictures|Capella International|KC Me...    6/30/2000
# 1888  Laurence Mark Productions|Columbia Pictures Co...    2/16/2000
# 1889                              Warner Bros. Pictures    7/19/2000
#
#      vote_count  vote_average  release_year      marjin      income  \
# 0          5562           6.5          2015  1363528810  1363528810
# 1          6185           7.1          2015   228436354   228436354
# 2          2480           6.3          2015   185238201   185238201
# 3          5292           7.5          2015  1868178225  1868178225
# 4          2947           7.3          2015  1316249360  1316249360
# ...         ...           ...           ...         ...         ...
# 1885       2766           6.6          2000    82299717    82299717
# 1886         42           6.4          2000    -8444012    -8444012
# 1887         35           4.0          2000   -40865180   -40865180
# 1888         21           5.2          2000    -3962091    -3962091
# 1889         12           5.2          2000    -9782502    -9782502
#
#       release_month movie_title_chars_count  movie_title_words_count
# 0                 6                      14                        2
# 1                 5                      18                        4
# 2                 3                       9                        1
# 3                12                      28                        5
# 4                 4                       9                        2
# ...             ...                     ...                      ...
# 1885              7                       5                        1
# 1886             10                      18                        3
# 1887              6                      36                        6
# 1888              2                      10                        2
# 1889              7                      12                        3
#
# [1890 rows x 21 columns]
# Counter({'Universal Pictures': 2.617142857142857,
#          'Paramount Pictures': 2.8688524590163933,
#          'Jim Henson Company, The': 10.0,
#          'Warner Bros': 2.73224043715847,
#          'Four By Two Productions': 12.0})
# 'Four By Two Productions'

# %%
answer_ls.append(5)

# %% [markdown]
# # 33. Сколько разных слов используется в названиях фильмов?(без учета регистра)
# Варианты ответа:
# 1. 6540
# 2. 1002
# 3. 2461
# 4. 28304
# 5. 3432

# %%
def split_title(title):
    words = title.lower().replace('&', '').split(' ')
    return words
data['movie_title_words'] = data['original_title'].apply(split_title)
words = data['movie_title_words'].explode().unique()
display(words)
print(len(words))
# Out:
# array(['jurassic', 'world', 'mad', ..., 'bullwinkle', 'hanging', 'crowd'],
#       dtype=object)
# 2461

# %%
answer_ls.append(3)

# %% [markdown]
# # 34. Какие фильмы входят в 1 процент лучших по рейтингу?
# Варианты ответа:
# 1. Inside Out, Gone Girl, 12 Years a Slave
# 2. BloodRayne, The Adventures of Rocky & Bullwinkle
# 3. The Lord of the Rings: The Return of the King
# 4. 300, Lucky Number Slevin

# %%
oneperc=data[data.vote_average > data.vote_average.quantile(.99)]['original_title'].reset_index()['original_title'].array
listmas_films= [
 ['Inside Out', 'Gone Girl', '12 Years a Slave'],
 ['BloodRayne', 'The Adventures of Rocky and Bullwinkle'],
 ['The Lord of the Rings: The Return of the King', 'Upside Down'],
 ['300', 'Lucky Number Slevin'],
 ['Upside Down', '300', 'Inside Out', 'The Lord of the Rings: The Return of the King']]

result= "There is no data!"
for i in range(0,len(listmas_films)):
    if all(elem in oneperc  for elem in listmas_films[i]):
        result= '|'.join(listmas_films[i]) 
        break  
print(result)
# Out:
# Inside Out|Gone Girl|12 Years a Slave

# %%
answer_ls.append(1)

# %% [markdown]
# # 35. Какие актеры чаще всего снимаются в одном фильме вместе
# Варианты ответа:
# 1. Johnny Depp & Helena Bonham Carter
# 2. Hugh Jackman & Ian McKellen
# 3. Vin Diesel & Paul Walker
# 4. Adam Sandler & Kevin James
# 5. Daniel Radcliffe & Rupert Grint

# %%
pairs = [
    ['Johnny Depp', 'Helena Bonham Carter'],
    ['Hugh Jackman', 'Ian McKellen'],
    ['Vin Diesel', 'Paul Walker'],
    ['Adam Sandler', 'Kevin James'],
    ['Daniel Radcliffe', 'Rupert Grint'],
]

artists_counter = Counter()
artists_list = []
for pair in pairs:
    artists_pair = ' & '.join(pair)
    artists_list.append(artists_pair)
    artists_counter[artists_pair] = len(data.loc[(data['cast'].str.contains(pair[0])) & (data['cast'].str.contains(pair[1]))])

display(artists_counter)  

artists_counter = pd.Series(artists_counter, index=artists_list)
display(artists_counter.idxmax())
# Out:
# Counter({'Johnny Depp & Helena Bonham Carter': 6,
#          'Hugh Jackman & Ian McKellen': 5,
#          'Vin Diesel & Paul Walker': 5,
#          'Adam Sandler & Kevin James': 5,
#          'Daniel Radcliffe & Rupert Grint': 8})
# 'Daniel Radcliffe & Rupert Grint'

# %%
answer_ls.append(5)

# %% [markdown]
# # 36. У какого из режиссеров выше вероятность выпустить фильм в прибыли? (5 баллов)101
# Варианты ответа:
# 1. Quentin Tarantino
# 2. Steven Soderbergh
# 3. Robert Rodriguez
# 4. Christopher Nolan
# 5. Clint Eastwood

# %%
directors = Counter()
for director in directors_list:
    movies = data.loc[(data['director'].str.contains(director))]
    profitable_movies = movies.loc[data['income'] > 0]
    directors[director] = len(profitable_movies) / len(movies)
    
display(directors)

directors_df = pd.Series(directors, index=directors_list)
display(directors_df.idxmax())
# Out:
# Counter({'Steven Soderbergh': 0.7692307692307693,
#          'Clint Eastwood': 0.8333333333333334,
#          'Ridley Scott': 1.0,
#          'Christopher Nolan': 1.0,
#          'Peter Jackson': 1.0})
# 'Ridley Scott'

# %%
answer_ls.append(4)

# %% [markdown]
# # Submission

# %%
len(answer_ls)
# Out:
# 60

# %%
pd.DataFrame({'Id':range(1,len(answer_ls)+1), 'Answer':answer_ls}, columns=['Id', 'Answer'])
# Out:
#     Id  Answer
# 0    1       1
# 1    2       3
# 2    3       4
# 3    4       5
# 4    5       1
# 5    6       3
# 6    7       3
# 7    8       2
# 8    9       1
# 9   10       4
# 10  11       2
# 11  12       3
# 12  13       1
# 13  14       5
# 14  15       1
# 15  16       4
# 16  17       2
# 17  18       5
# 18  19       2
# 19  20       5
# 20  21       5
# 21  22       3
# 22  23       1
# 23  24       5
# 24  25       4
# 25  26       4
# 26  27       2
# 27  28       3
# 28  29       2
# 29  30       1
# 30  31       5
# 31  32       2
# 32  33       1
# 33  34       4
# 34  35       5
# 35  36       3
# 36  37       1
# 37  38       3
# 38  39       4
# 39  40       5
# 40  41       1
# 41  42       3
# 42  43       3
# 43  44       2
# 44  45       1
# 45  46       4
# 46  47       2
# 47  48       3
# 48  49       1
# 49  50       5
# 50  51       1
# 51  52       2
# 52  53       5
# 53  54       2
# 54  55       5
# 55  56       5
# 56  57       3
# 57  58       1
# 58  59       5
# 59  60       4

# %%
import pandas as pd

# Вводим данные
df = pd.read_csv('data.csv')

# Список киностудий
company = df['production_companies']

# Подсчитываем число вхождений каждой киностудии
counter = {}
for k in company: 
    counter[k] = counter.setdefault(k, 0) + 1

# Сортируем по количеству фильмов
sc = sorted(counter.items(), key=lambda t: t[1])

# Печатаем результат
for k,v in sc:
    print(k, v)
# Out:
# Universal Studios|Amblin Entertainment|Legendary Pictures|Fuji Television Network|Dentsu 1
# Village Roadshow Pictures|Kennedy Miller Productions 1
# Summit Entertainment|Mandeville Films|Red Wagon Entertainment|NeoReel 1
# Lucasfilm|Truenorth Productions|Bad Robot 1
# Universal Pictures|Original Film|Media Rights Capital|Dentsu|One Race Films 1
# Regency Enterprises|Appian Way|CatchPlay|Anonymous Content|New Regency Pictures 1
# Paramount Pictures|Skydance Productions 1
# Twentieth Century Fox Film Corporation|Scott Free Productions|Mid Atlantic Films|International Traders|TSG Entertainment 1
# Walt Disney Pictures|Pixar Animation Studios|Walt Disney Studios Motion Pictures 1
# Columbia Pictures|Danjaq|B24 1
# Village Roadshow Pictures|Dune Entertainment|Anarchos Productions|Warner Bros. 1
# DNA Films|Universal Pictures International (UPI)|Film4 1
# Marvel Studios|Prime Focus|Revolution Sun Studios 1
# Double Feature Films|The Weinstein Company|FilmColony 1
# Twentieth Century Fox Film Corporation|M6 Films|Canal+|EuropaCorp|CinÃ©+ 1
# Walt Disney Pictures|Genre Films|Beagle Pug Films|Allison Shearmur Productions 1
# Studio Babelsberg|StudioCanal|Lionsgate|Walt Disney Studios Motion Pictures|Color Force 1
# Walt Disney Pictures|Babieka|A113 1
# Escape Artists|Riche-Ludwig Productions 1
# New Line Cinema|Village Roadshow Pictures|Warner Bros.|Flynn Picture Company 1
# Focus Features|Trigger Street Productions|Michael De Luca Productions 1
# Paramount Pictures|Plan B Entertainment|Regency Enterprises 1
# Paramount Pictures|Skydance Productions|China Movie Channel|Bad Robot|TC Productions 1
# Twentieth Century Fox Film Corporation|Marv Films|TSG Entertainment|Cloudy Productions 1
# Participant Media|Open Road Films|Anonymous Content|Rocklin / Faust|Entertainment One Features 1
# Gotham Group|Temple Hill Entertainment|TSG Entertainment 1
# Columbia Pictures|Media Rights Capital|Sony Pictures Entertainment (SPE)|Alpha Core|Genre Films 1
# Universal Pictures|Gold Circle Films|Brownstone Productions 1
# DreamWorks SKG|Amblin Entertainment|Studio Babelsberg|Fox 2000 Pictures|Marc Platt Productions 1
# Columbia Pictures|Original Film|Scholastic Entertainment 1
# Element Pictures|No Trace Camping|A24|Duperele Films 1
# Walt Disney Pictures|Pixar Animation Studios|Buena Vista 1
# Vertigo Entertainment|Energy Entertainment|RatPac-Dune Entertainment 1
# Wildgaze Films|Irish Film Board|Item 7|Parallel Film Productions 1
# New Line Cinema|Universal Pictures|Legendary Pictures|Cube Vision|Broken Chair Flickz 1
# Summit Entertainment|Atmosphere Entertainment MM|One Race Films|Goldmann Pictures|NeoReel 1
# Davis Entertainment|Warner Bros.|Wigram Productions|RatPac-Dune Entertainment 1
# Lakeshore Entertainment|Sidney Kimmel Entertainment|Sierra/Affinity 1
# Bazelevs Production|Versus Pictures 1
# Twentieth Century Fox Film Corporation|DreamWorks Animation 1
# Killer Films|Film4|Number 9 Films 1
# Waverly Films|Warner Bros. 1
# Universal Pictures|Working Title Films|Walden Media|Cross Creek Pictures|Free State Pictures 1
# Studio Babelsberg|Alcon Entertainment|DMG Entertainment|Ehman Productions 1
# Double Feature Films|PeaPie Films|3 Arts Entertainment 1
# Endgame Entertainment|Ram Bergman Productions 1
# Lionsgate|Mad Chance|OddLot Entertainment|Huayi Brothers Media 1
# Pretty Pictures|Working Title Films|ArtÃ©mis Productions|Le Tax Shelter du Gouvernement FÃ©dÃ©ral de Belgique|Taxshelter. be 1
# Universal Pictures|Forward Pass|Legendary Pictures 1
# Lionsgate|Thunder Road Pictures|Black Label Media 1
# Twentieth Century Fox Film Corporation|Marv Films|Marvel Entertainment|Constantin Film.|Moving Picture Company (MPC) 1
# Twentieth Century Fox Film Corporation|Chernin Entertainment|Feigco Entertainment 1
# Kramer & Sigman Films|RatPac-Dune Entertainment|Zaftig Films 1
# Twentieth Century Fox Film Corporation|Fox International Productions|Infinite Frameworks Studios|TSG Entertainment 1
# Imagine Entertainment|Spring Creek Productions|Warner Bros.|Roth Films|K. JAM Media 1
# New Line Cinema|Warner Bros.|Metro-Goldwyn-Mayer (MGM)|Chartoff-Winkler Productions 1
# Universal Pictures|Fuji Television Network|Dentsu|Apatow Productions 1
# Entertainment One|Moonlighting Films|Raindog Films 1
# Working Title Films|Cross Creek Pictures|Anton Capital Entertainment (ACE) 1
# Warner Bros.|Moving Picture Company (MPC)|Berlanti Productions|RatPac-Dune Entertainment 1
# Blue Sky Studios|Twentieth Century Fox Animation|Feigco Entertainment 1
# Village Roadshow Pictures|Scott Free Productions|LStar Capital|The Cantillon Company|The Shuman Company 1
# Sony Pictures|Point Grey Pictures|Good Universe 1
# Fox 2000 Pictures|Temple Hill Entertainment 1
# Imagine Entertainment|Groundswell Productions|CBS Films 1
# TriStar Pictures|Sony Pictures Entertainment|ImageMovers 1
# New Line Cinema|BenderSpink|David Dobkin Productions 1
# Ghost House Pictures|Vertigo Entertainment|Metro-Goldwyn-Mayer (MGM)|TSG Entertainment 1
# Summit Entertainment|Scott Free Productions|Worldview Entertainment 1
# Blumhouse Productions|Blue-Tongue Films|STX Entertainment|Ahimsa Films 1
# Paramount Pictures|Gary Sanchez Productions|Good Universe|Red Granite Pictures 1
# Onyx Films|Orange Studios|CityMation|On Entertainment|Zippcast Films 1
# Amazon Studios|Film Art Media|Apollo Media 1
# Wonderland Sound and Vision|CBS Films|Vast Entertainment 1
# Alliance Films|Blumhouse Productions|IM Global|Automatik Entertainment|Entertainment One 1
# Columbia Pictures|Happy Madison Productions|Sony Pictures Releasing|Sony Pictures Home Entertainment|Sony Pictures Entertainment (SPE) 1
# Warner Bros.|Closest to the Hole Productions 1
# Miramax Films|Screen Gems|LStar Capital 1
# Blumhouse Productions|Blinding Edge Pictures 1
# Infinitum Nihil|Head Gear Films|Cross Creek Pictures|Free State Pictures|RatPac-Dune Entertainment 1
# Universal Pictures|Legendary Pictures 1
# Bold Films|Living Films|Brothers Dowdle Productions 1
# BBC Films|Origin Pictures 1
# Little Stranger 1
# Paramount Pictures|MTV Films|Platinum Dunes|Insurge Pictures 1
# Warner Bros.|Iron Horse Entertainment (II) 1
# Paramount Pictures|Blumhouse Productions 1
# Groundswell Productions|Inimitable Pictures|ShivHans Pictures 1
# Ingenious Media|Gran Via Productions|IM Global|Route One Films 1
# Paramount Pictures|Nickelodeon Movies|Nickelodeon Animation Studios|United Plankton Pictures|Disruption Entertainment 1
# Sunswept Entertainment|Warner Bros.|Metro-Goldwyn-Mayer (MGM) 1
# StudioCanal|Silver Pictures|TF1 Films Production|Canal+|Instituto de la CinematografÃ­a y de las Artes Audiovisuales (ICAA) 1
# New Line Cinema|Warner Bros.|Metro-Goldwyn-Mayer (MGM)|Pacific Standard 1
# BBC Films|TriStar Productions 1
# Twentieth Century Fox Film Corporation|Davis Entertainment|Moving Picture Company (MPC)|TSG Entertainment 1
# Columbia TriStar|Clinica Estetico|LStar Capital 1
# Scott Rudin Productions|A24 1
# Gary Sanchez Productions|Warner Bros. 1
# Ruby Films|PathÃ©|Film4 1
# Metanoia Films 1
# Columbia Pictures|Vinyl Films|Regency Enterprises|Sony Pictures Entertainment (SPE)|RatPac Entertainment 1
# Participant Media|Smokehouse Pictures 1
# Shangri-La Entertainment|QED International|Dune Films|Venture Forth 1
# Wildwood Enterprises|Route One Films 1
# Studio Babelsberg|Regency Enterprises|Escape Artists|New Regency Pictures 1
# Universal Pictures|Blumhouse Productions|Hasbro Studios|Allspark Pictures 1
# Paramount Pictures|Legendary Pictures|Warner Bros.|Syncopy|Lynda Obst Productions 1
# Marvel Studios|Moving Picture Company (MPC)|Bulletproof Cupid|Revolution Sun Studios 1
# Thunder Road Pictures|Warner Bros.|87Eleven|DefyNite Films|MJW Films 1
# WingNut Films|New Line Cinema|3Foot7|Metro-Goldwyn-Mayer (MGM) 1
# Black Bear Pictures|Bristol Automotive 1
# Ingenious Media|Twentieth Century Fox Film Corporation|Gotham Group|Dayday Films|Temple Hill Entertainment 1
# Worldview Entertainment|New Regency Pictures|TSG Entertainment|Le Grisbi Productions|M Productions 1
# Twentieth Century Fox Film Corporation|Regency Enterprises|New Regency Pictures|Pacific Standard|TSG Entertainment 1
# Columbia Pictures|QED International|Crave Films|LStar Capital|Huayi Brothers Media 1
# Twentieth Century Fox Film Corporation|1492 Pictures|21 Laps Entertainment|Moving Picture Company (MPC)|TSG Entertainment 1
# Summit Entertainment|Red Wagon Entertainment 1
# Twentieth Century Fox Film Corporation|Donners' Company|Marvel Entertainment|Bad Hat Harry Productions|TSG Entertainment 1
# Universal Pictures|TF1 Films Production|Canal+|EuropaCorp|CinÃ©+ 1
# Paramount Pictures|Nickelodeon Movies|Platinum Dunes 1
# Escape Artists|Media Rights Capital|Sony Pictures Entertainment (SPE)|LStar Capital 1
# Bold Films|Sierra / Affinity 1
# Paramount Pictures|Amblin Entertainment|Di Bonaventura Pictures|Platinum Dunes|Hasbro 1
# Fox Searchlight Pictures|Scott Rudin Productions|Studio Babelsberg|Indian Paintbrush|TSG Entertainment 1
# Ingenious Media|Chernin Entertainment|TSG Entertainment 1
# Columbia Pictures|Village Roadshow Pictures|Escape Artists|Mace Neufeld Productions|LStar Capital 1
# New Line Cinema|BenderSpink|RatPac Entertainment 1
# Columbia Pictures|Marvel Enterprises|Avi Arad Productions|Matt Tolmach Productions 1
# Village Roadshow Pictures|Warner Bros.|Viz Media|Province of British Columbia Production Services Tax Credit|3 Arts Entertainment 1
# Columbia TriStar 1
# Village Roadshow Pictures|Malpaso Productions|Warner Bros.|RatPac-Dune Entertainment|Mad Chance Productions 1
# Scott Free Productions|Chernin Entertainment|Babieka|Volcano Films 1
# Toho Company|Legendary Pictures|Warner Bros.|Disruption Entertainment|RatPac-Dune Entertainment 1
# Irish Dreamtime|Relativity Media|SPD Films 1
# Universal Pictures|Platinum Dunes|Media Rights Capital|Hasbro|Blumhouse Productions 1
# DreamWorks Animation|Mad Hatter Entertainment 1
# Davis-Films|Nu Image Films|LionsGate|Millennium Films|Ex3 Productions 1
# Village Roadshow Pictures|DC Comics|Vertigo Entertainment|Lin Pictures|Warner Bros. Animation 1
# Legendary Pictures|Thunder Road Pictures|Outlaw Sinema|Moving Picture Company (MPC)|Pendle Mountain Productions 1
# Twentieth Century Fox Film Corporation|WideAwake|Genre Films 1
# Universal Pictures|Legendary Pictures|Fuji Television Network|Dentsu|Michael De Luca Productions 1
# Walt Disney Pictures|Marc Platt Productions|Lucamar Productions 1
# Legendary Pictures|Hollywood Gang Productions|Atmosphere Entertainment MM|Warner Bros.|Nimar Studios 1
# The Weinstein Company|Walden Media|Tonik Productions|Asis Productions 1
# Columbia Pictures|Original Film|Media Rights Capital|Metro-Goldwyn-Mayer (MGM)|Cannell Studios 1
# Double Feature Films|Jersey Films|1984 Private Defense Contractors|Cross Creek Pictures|Exclusive Media Group 1
# The Weinstein Company|StudioCanal|TF1 Films Production|Canal+|Heyday Films 1
# Echo Films|We're Not Brothers Productions|Cinelou Films 1
# Open Road Films|Aldamisa Entertainment|Kilburn Media|Fetisov Teterin Films 1
# Universal Pictures|Why Not Productions|Platinum Dunes|Blumhouse Productions|5150 Action 1
# Stoney Lake Entertainment 1
# Participant Media|Imagenation Abu Dhabi FZ|FilmNation Entertainment|Before the Door Pictures|Washington Square Films 1
# Paramount Pictures|Metro-Goldwyn-Mayer (MGM)|Radical Studios|Flynn Picture Company 1
# Paramount Pictures|Regency Enterprises|Protozoa Pictures|Disruption Entertainment 1
# Village Roadshow Pictures|Warner Bros.|Big Kid Pictures|Team Downey 1
# Happy Madison Productions|Karz Entertainment|Warner Bros.|Gulfstream Pictures 1
# Universal Pictures|Point Grey Pictures|Good Universe 1
# New Line Cinema|Metro-Goldwyn-Mayer (MGM) 1
# Summit Entertainment|Offspring Entertainment 1
# Fox 2000 Pictures|Temple Hill Entertainment|TSG Entertainment 1
# Universal Pictures|Rainforest Films|Cube Vision|Relativity Media 1
# Ghoulardi Film Company|Warner Bros. 1
# Paramount Pictures|Di Bonaventura Pictures|Mace Neufeld Productions|Skydance Productions|Etalon film 1
# StudioCanal|Silver Pictures|TF1 Films Production|Canal+|Anton Capital Entertainment (ACE) 1
# Screen Australia|Screen Queensland|Blacklab Entertainment|Wolfhound Pictures 1
# Columbia Pictures|Strike Entertainment|Metro-Goldwyn-Mayer (MGM) 1
# Alcon Entertainment|Syncopy|DMG Entertainment|Straight Up Films 1
# Twentieth Century Fox Film Corporation|LBI Productions 1
# Miramax Films|Troublemaker Studios|AR Films|Aldamisa Entertainment|Demarest Films 1
# New Line Cinema|Universal Pictures|Conundrum Entertainment|Red Granite Pictures 1
# Columbia Pictures|Studio Babelsberg|Fox 2000 Pictures|Smokehouse Pictures|Obelisk Productions 1
# Legendary Pictures|3 Arts Entertainment|Jolie Pas 1
# Plan B Entertainment|Harpo Films|Celador Films|Cloud Eight Films|PathÃ© 1
# Impact Pictures|TriStar Pictures|Don Carmody Productions|FilmDistrict|Constantin Film International 1
# Columbia Pictures|Sony Pictures Entertainment (SPE)|Overbrook Entertainment 1
# The Weinstein Company|Crescendo Productions|Chernin Entertainment|Goldenlight Films 1
# DreamWorks SKG|Reliance Entertainment|Bandito Brothers|Touchstone Pictures|Electronic Arts 1
# Amblin Entertainment|Harpo Films|Participant Media|Imagenation Abu Dhabi FZ|Reliance Entertainment 1
# Laika Entertainment 1
# The Weinstein Company|Silverwood Films|Electric City Entertainment|Tim Burton Productions 1
# Grindstone Entertainment Group|Emmett/Furla Films|Oasis Films|Aperture Entertainment 1
# New Line Cinema|Village Roadshow Pictures|Broken Road Productions 1
# Walt Disney Pictures|DisneyToon Studios|Prana Studios|Prana Animation Studios 1
# Open Road Films|QED International|Albert S. Ruddy Productions|Crave Films|Roth Films 1
# Likely Story|Media Rights Capital|Annapurna Pictures 1
# Universal Pictures|Fake Empire|Bluegrass Films 1
# Porchlight Films|FilmNation Entertainment|Screen Australia|Screen NSW|Blue-Tongue Films 1
# Qwerty Films|Alliance Films|Canal+|TF1 Droits Audiovisuels|Scope Pictures 1
# New Line Cinema|The Safran Company|Evergreen Media Group|RatPac-Dune Entertainment 1
# Lakeshore Entertainment|Sidney Kimmel Entertainment|Lionsgate|Hopscotch Films 1
# Canal+|EuropaCorp|CinÃ©+|D8 1
# New Line Cinema|Gary Sanchez Productions 1
# Village Roadshow Pictures|Weed Road Pictures|Warner Bros. 1
# HanWay Films|Snoot Entertainment 1
# Hopscotch Features|RatPac Entertainment|Seven West Media|Fear of God Films|Seven Group Holdings 1
# Walt Disney Pictures|21 Laps Entertainment|Jim Henson Company, The 1
# Spring Creek Productions|21 Laps Entertainment|Warner Bros. 1
# Screen Gems, Inc.|Rainforest Films|Olive Bridge Entertainment 1
# Scottish Screen|UK Film Council|FilmNation Entertainment|Nick Wechsler Productions|Creative Scotland 1
# Warner Bros.|Warner Bros. Interactive Entertainment|Rob Thomas Productions 1
# Hearst Entertainment Productions|LightWorkers Media 1
# Mandalay Pictures|Affirm Films 1
# Fox International Productions|Sahara Productions|Silvatar Media 1
# The Combine|Bluegrass Films 1
# Alcon Entertainment|Color Force|Boxing Cat Films 1
# Buena Vista|Disney 1
# TriStar Pictures|Screen Gems|Roth Films 1
# TriStar Pictures|Provident Films|Pure Flix Entertainment|Affirm Films|FourBoys Entertainment 1
# Walt Disney Studios Motion Pictures|Panay Films 1
# Paramount Pictures|Winkler Films 1
# Max Films Productions|Morag Loves Company 1
# Pure Flix Entertainment 1
# Twentieth Century Fox Film Corporation|Davis Entertainment|TSG Entertainment 1
# Ingenious Film Partners|Twentieth Century Fox Film Corporation|Dune Entertainment|Lightstorm Entertainment 1
# Universal Pictures|A Band Apart|Zehnte Babelsberg|Visiona Romantica 1
# Lakeshore Entertainment|Screen Gems|Sketch Films|UW3 Film Productions 1
# Paramount Pictures|Spyglass Entertainment|Bad Robot|MavroCine Pictures GmbH & Co. KG 1
# Columbia Pictures|The Halcyon Company|Wonderland Sound and Vision|Warner Bros. 1
# WingNut Films|TriStar Pictures|Key Creatives|Block / Hanson|Canadian Film or Video Production Tax Credit (CPTC) 1
# Village Roadshow Pictures|Silver Pictures|Warner Bros.|Internationale Filmproduktion Blackbird Dritte|Wigram Productions 1
# Fox Searchlight Pictures|Watermark|Dune Entertainment III 1
# Legendary Pictures|Green Hat Films|Warner Bros.|IFP Westcoast Erste 1
# Paramount Pictures|DC Comics|Lawrence Gordon Productions|Legendary Pictures|Warner Bros. 1
# Columbia Pictures|Centropolis Entertainment|The Mark Gordon Company|Farewell Productions 1
# Focus Films|Starz Animation|Relativity Media|Tim Burton Productions|Arc Productions 1
# Columbia Pictures|Imagine Entertainment|Panorama Films|Skylark Productions 1
# Alcon Entertainment|Left Tackle Pictures|Zucker/Netter Productions 1
# New Line Cinema|Flower Films (II)|Internationale Filmproduktion Blackswan 1
# Paramount Pictures|Spyglass Entertainment|Di Bonaventura Pictures|Hasbro|Kontsept Film Company 1
# Touchstone Pictures|Mandeville Films|Kurtzman/Orci 1
# Lakeshore Entertainment|Relativity Media 1
# Twentieth Century Fox Film Corporation|Regency Enterprises|Indian Paintbrush|Twentieth Century Fox Animation|American Empirical Pictures 1
# Twentieth Century Fox Film Corporation|1492 Pictures|Dune Entertainment|21 Laps Entertainment|Museum Canada Productions 1
# Walt Disney|ImageMovers 1
# WingNut Films|DreamWorks SKG|Key Creatives|Film4|Goldcrest Pictures 1
# Grand Army Entertainment|Scion Films|Inferno Distribution|Stage 6 Films|Hachiko 1
# Film Department, The|Evil Twins|Warp Films 1
# Media Rights Capital|Lin Pictures|Warner Bros.|Darko Entertainment|Radar Pictures 1
# Lakeshore Entertainment|Lionsgate|Radical Media 1
# Impact Pictures|Constantin Film Produktion 1
# Universal Pictures|Ghost House Pictures|Mandate Pictures|Buckaroo Entertainment|Curse Productions 1
# Summit Entertainment|Mystery Clock Cinema|Escape Artists|Goldcrest Pictures|Kaplan/Perrone Entertainment 1
# Liberty Films UK|Lunar Industries|Xingu Films|Limelight Fund 1
# Walt Disney Pictures|Jerry Bruckheimer Films|Whamaphram Productions 1
# Columbia Pictures|Escape Artists|Scott Free Productions|Relativity Media|Metro-Goldwyn-Mayer (MGM) 1
# Media Rights Capital|Lin Pictures|Warner Bros.|Wintergreen Productions|Lynda Obst Productions 1
# Lakeshore Entertainment|Lionsgate 1
# Pan EuropÃ©enne Production|Virtual Films 1
# Universal Pictures|Wild West Picture Show Productions|Stuber Productions|Relativity Media 1
# Lionsgate|Relativity Media|Sighvatsson Films|Michael De Luca Productions|Palomar Pictures (II) 1
# 2929 Productions|Dimension Films|Nick Wechsler Productions|Chockstone Pictures 1
# Columbia Pictures|Scott Rudin Productions|Easy There Tiger Productions 1
# StudioCanal|Montecito Picture Company, The|Outpost Studios 1
# Universal Pictures|Appian Way|Forward Pass|Dentsu|Relativity Media 1
# Dune Entertainment|Fox Atomic 1
# Dark Castle Entertainment|Studio Babelsberg StudioBabelsberg Motion Pictures|Don Carmody Productions|Studio Canal 1
# Dune Entertainment|Fox 2000 Pictures|Fortis Films|Dune Entertainment III|Radar Pictures 1
# Regency Enterprises|Fox 2000 Pictures|Bagdasarian Productions 1
# Dune Entertainment|Regency Enterprises|Fox 2000 Pictures|Dune Entertainment III|New Regency Pictures 1
# Smokewood Entertainment Group 1
# Universal Pictures|StudioCanal|Andell Entertainment|Relativity Media|Working Title Films 1
# Rogue Pictures|Phantom Four|Platinum Dunes|Relativity Media 1
# DreamWorks SKG|The Montecito Picture Company|De Line Pictures|Bernard Gayle Productions 1
# Section Eight|Groundswell Productions|Warner Bros.|Participant Media|Jaffe / Braunstein Enterprise 1
# Walt Disney Pictures|Gunn Films 1
# Paramount Vantage|Anonymous Content|Misher Films|Case 39 Productions 1
# Universal Pictures|Studio Canal|Working Title Films|Medienproduktion Prometheus Filmgesellschaft|Portobello Studios 1
# Lionsgate|Furst Films|Pictures in Paradise|Pacific Film and Television Commission|Australian Film Finance Corporation (AFFC) 1
# Universal Pictures|Stuber Productions|Camp / Thompson Pictures|Relativity Media|Scion Films 1
# Icon Productions|Infinity Features Entertainment|Summit Entertainment 1
# Nu Image Films|Langley Productions|Thunder Road Productions|Fuqua Films|Millennium Films 1
# GK Films 1
# Davis Entertainment|Relativity Media|Rogue|QED International|Tooley Productions 1
# StudioCanal|Dark Castle Entertainment|Don Carmody Productions|Warner Bros.|Canadian Film or Video Production Tax Credit (CPTC) 1
# The Mark Gordon Company|Fox Atomic|20th Century Fox Home Entertainment|WWE Studios|Midnight Sun Pictures 1
# Vidhu Vinod Chopra Productions 1
# BBC Films|Smoke House 1
# Studio Babelsberg|Anarchos Productions|Legendary Pictures|Dark Castle Entertainment|Silver Pictures 1
# Summit Entertainment|Goldsmith-Thomas Productions|Walden Media 1
# Universal Pictures|Scott Rudin Productions|Waverly Films|Dentsu|Relativity Media 1
# Universal Pictures|Mosaic Media Group|Relativity Media|Sid & Marty Krofft Pictures 1
# Spyglass Entertainment|Malpaso Productions|Revelations Entertainment|Mace Neufeld Productions|Warner Bros. 1
# TriStar Pictures|Ilion Animation Studios|Hand Made Films 1
# Columbia Pictures|Ocean Pictures|Apatow Productions 1
# Walt Disney Pictures|Tapestry Films 1
# HimenÃ³ptero|Telecinco Cinema|Mod Producciones|Nimar Studios|Canal+ EspaÃ±a 1
# Chris Brinker Productions|Stage 6 Films 1
# Saturn Films|Nu Image Films|Edward R. Pressman Film|Millennium Films|Polsky Films 1
# Screen Gems|Stars Road Entertainment|Farah Films & Management|Buckaroo Entertainment 1
# Columbia Pictures|Universal Pictures|Happy Madison Productions|Relativity Media|Apatow Productions 1
# The Weinstein Company|Summit Entertainment|Tezuka Production Company Ltd.|Imagi Animation Studios 1
# Studio Babelsberg|Atlas Entertainment|Mosaic Media Group|X-Filme Creative Pool 1
# Universal Pictures|Original Film|One Race Productions|Dentsu Inc.|Relativity Media 1
# The Weinstein Company|Paramount Vantage 1
# Dimension Films|Spectacle Entertainment Group|Trancas International Films 1
# Walt Disney Pictures|It's a Laugh Productions|Millar Gough Ink 1
# Twentieth Century Fox Film Corporation|Regency Enterprises|Josephson Entertainment|New Upstairs Productions|Upstairs Canada Productions 1
# Universal Pictures|Saga Film|Focus Films|Gold Circle Films|Chambara Pictures 1
# Smartest Man Productions|Millennium Films|Paul Schiff Productions 1
# Universal Pictures|Laura Bickford Productions|Relativity Media|Medienproduktion Poseidon Filmgesellschaft 1
# BBC Films|PathÃ© Renn Productions|UK Film Council|Screen Australia|Australian Film Finance Corporation (AFFC) 1
# Miramax Films|Sidney Kimmel Entertainment|This Is That Productions 1
# Fox Searchlight Pictures|26 Films 1
# Mark Johnson Productions|Gran Via Productions|Curmudgeon Films 1
# HanWay Films|UK Film Council|Marv Films 1
# Touchstone Pictures|Mandeville Films|Wintergreen Productions|Top Shelf Productions 1
# Twentieth Century Fox Film Corporation|Hyde Park Films 1
# DreamWorks SKG|Nickelodeon Movies 1
# Davis-Films|Czech Anglo Productions|Wandering Star Pictures 1
# Ingenious Film Partners|Twentieth Century Fox Film Corporation|Donners' Company|Dune Entertainment|Seed Productions 1
# Lionsgate|Edmonds Entertainment Group (EEG)|Epidemic Pictures|The Safran Company|Gold Circle Films 1
# Isle of Man Film|Freestyle Releasing|CinemaNX 1
# Summit Entertainment|Karz Entertainment 1
# Echo Lake Productions|Premiere Picture 1
# Dune Entertainment|Cold Spring Pictures|The Montecito Picture Company|Fox Atomic 1
# Fox Searchlight Pictures|Butcher's Run Films|Informant Media 1
# Columbia Pictures|Castle Rock Entertainment|Relativity Media|Banter 1
# Ghost House Pictures|Ozla Pictures|Stage 6 Films 1
# Great Scott Productions Pty. Ltd. 1
# Legendary Pictures|Warner Bros.|Syncopy 1
# Walt Disney Pictures|Team Todd|Tim Burton Productions|Roth Films|Zanuck Company, The 1
# Fox Searchlight Pictures|Dune Entertainment|Protozoa Pictures|Cross Creek Pictures 1
# DreamWorks Animation|Vertigo Entertainment|Mad Hatter Entertainment 1
# Paramount Pictures|Appian Way|Phoenix Pictures|Sikelia Productions 1
# Walt Disney Pictures|LivePlanet|Prana Studios|Sean Bailey Productions|Revolution Sun Studios 1
# Columbia Pictures|Di Bonaventura Pictures|Relativity Media|Wintergreen Productions 1
# Fox Searchlight Pictures|Dune Entertainment|Darlow Smithson Productions|Warner Bros.|Cloud Eight Films 1
# Screen Gems|Olive Bridge Entertainment 1
# Dune Entertainment|Fox 2000 Pictures|Walden Media 1
# Lions Gate 1
# Spyglass Entertainment|Peninsula Films|StudioCanal|GK Films|Italian Tax Credit 1
# Imagine Entertainment|Universal Pictures|Scott Free Productions|Relativity Media 1
# Paramount Pictures|Scott Rudin Productions|Mike Zoss Productions|Skydance Productions 1
# The Zanuck Company|Legendary Pictures|Thunder Road Pictures|Warner Bros.|Moving Picture Company (MPC) 1
# Walt Disney Pictures|Jerry Bruckheimer Films|Saturn Films|Broken Road Productions|Junction Entertainment 1
# Columbia Pictures|Scott Rudin Productions|Relativity Media 1
# Universal Pictures|Marc Platt Productions 1
# Paramount Pictures|Universal Pictures|Everyman Pictures|Relativity Media|Dreamworks Pictures 1
# Twentieth Century Fox Film Corporation|Davis Entertainment|Dune Entertainment III|Troublemaker Studios 1
# Ingenious Film Partners|1492 Pictures|Dune Entertainment|Fox 2000 Pictures|Sunswept Entertainment 1
# Twentieth Century Fox Film Corporation|Scott Free Productions|Firm Films|Prospect Park|Millbrook Farm Productions 1
# DC Comics|Di Bonaventura Pictures|Summit Entertainment|DC Entertainment 1
# Dune Entertainment|Dune Entertainment III|Troublemaker Studios|Overnight Films 1
# Alcon Entertainment|Silver Pictures 1
# Twentieth Century Fox Film Corporation|Dune Entertainment|21 Laps Entertainment 1
# Legendary Pictures|GK Films|Thunder Road Pictures|Warner Bros. 1
# Paramount Pictures|Nickelodeon Movies|Kennedy/Marshall Company, The|Industrial Light & Magic (ILM)|Blinding Edge Pictures 1
# Columbia Pictures|Gary Sanchez Productions 1
# Summit Entertainment|Touchstone Pictures 1
# The Weinstein Company|UK Film Council|Bedlam Productions|See-Saw Films|Aegis Film Fund 1
# Bedford Falls Productions|Dune Entertainment|Regency Enterprises|Fox 2000 Pictures|Stuber Productions 1
# Polish Film Institute|Imagenation Abu Dhabi FZ|Exclusive Films|Monolith Films|On the Road 1
# Universal Pictures|Stuber Productions|Dentsu|Relativity Media 1
# Tree Line Films|Twentieth Century Fox Film Corporation|Dune Entertainment|Regency Enterprises|Pink Machine 1
# Columbia Pictures|Red Om Films|Plan B Entertainment 1
# Columbia Pictures|Original Film|Relativity Media|Madhouse Entertainment 1
# Universal Pictures|Spyglass Entertainment|Octagon Films|BenderSpink|Birnbaum/Barber 1
# Universal Pictures|StudioCanal|Dentsu|Relativity Media|Working Title Films 1
# Twentieth Century Fox Film Corporation|Dune Entertainment|Davis Entertainment|Dune Entertainment III 1
# Escape Artists|CBS Films 1
# Universal Pictures|Marc Platt Productions|Relativity Media 1
# Mandate Pictures|Bona Fide Productions|Echo Films 1
# River Road Entertainment|Road Rebel|Linson Entertainment 1
# New Line Cinema|Karz Entertainment|Rice Films 1
# Miramax Films|Gran Via Productions|FilmDistrict|Necropia|Tequila Gang 1
# Lionsgate|Twisted Pictures|Serendipity Productions 1
# Columbia Pictures|Jerry Weintraub Productions|China Film Group|Overbrook Entertainment 1
# Legendary Pictures|Green Hat Films|Warner Bros. 1
# Matador Pictures|Isle of Man Film|Magic Light Pictures|CinemaNX|Cinema Four 1
# Studio Babelsberg|Runteam Ltd.|R.P. Productions|France 2 CinÃ©ma 1
# Lionsgate|FidÃ©litÃ© Films|Hwy61 1
# New Line Cinema|Platinum Dunes 1
# Universal Pictures|Spyglass Entertainment|Relativity Media|Apatow Productions 1
# Katalyst Films|Lionsgate|Aversano Films 1
# Bold Films 1
# New Line Cinema|Village Roadshow Pictures|Home Box Office (HBO)|HBO Films 1
# Oops Doughnuts Productions|Touchstone Pictures|Frontier Pictures 1
# Universal Pictures|Three Strange Angels|Studio Canal|Relativity Media|Working Title Films 1
# United Artists|Metro-Goldwyn-Mayer (MGM)|New Crime Productions 1
# Hammer Film Productions|EFTI|Exclusive Media Group|Overture Films 1
# Village Roadshow Pictures|Warner Bros.|Animal Logic|Cruel and Unusual Films 1
# Bedford Falls Productions 1
# Spring Creek Productions|Battle Mountain Films 1
# Fox Searchlight Pictures|DNA Films|Film4 1
# Josephson Entertainment|Gold Circle Films|Village Roadshow Pictures Asia 1
# PathÃ© Pictures International|UK Film Council|Celador Films|Canal+|Warner Bros. 1
# Stone Productions|Mimran Schur Pictures 1
# Color Force 1
# The Weinstein Company|Atmosphere Entertainment MM|Chako Film Company|Dimension Films|Intellectual Properties Worldwide 1
# Bad Robot|Goldcrest Pictures 1
# Oceana Media Finance|Pantheon Entertainment Corporation|Innocence Productions|Prescience|Omega Entertainment 1
# Dune Entertainment|Dune Entertainment III|Twentieth Century Fox|Walden Media|Mayhem Pictures 1
# River Road Entertainment|Participant Media 1
# Paramount Pictures|DreamWorks SKG|Spyglass Entertainment|Everyman Pictures|Reliance BIG Entertainment 1
# Rogue Pictures|Relativity Media|Hydraulx|Rat Entertainment|Transmission Pictures 1
# Miramax Films|Marv Films|Pioneer Pictures 1
# Village Roadshow Pictures 1
# Columbia Pictures|Gracie Films|Road Rebel 1
# Robert Simonds Productions|Relativity Media|Spy Next Door 1
# DreamWorks SKG|Mosaic 1
# GK Films|Henceforth|Projection Pictures|London Boulevard 1
# Amblin Entertainment|Malpaso Productions|Warner Bros.|Kennedy/Marshall Company, The 1
# Relativity Media|Rogue 1
# Wildwood Enterprises|American Film Company 1
# Parabolic Pictures|Screen Gems 1
# Twentieth Century Fox Film Corporation|Dune Entertainment|Dune Entertainment III|Edward R. Pressman Film 1
# Birdsong Pictures|IM Global 1
# Penn Station Entertainment|Participant Media|Imagenation Abu Dhabi FZ|Overture Films 1
# Lions Gate Family Entertainment|Relativity Media|Crest Animation Productions 1
# De Line Pictures|Warner Bros. Animation|Sunswept Entertainment|Rhythm and Hues|Picnic Basket 1
# Maguire Entertainment|Screen Gems|Sony Pictures Home Entertainment 1
# Omnilab Media|Ambience Entertainment 1
# Double Feature Films|CBS Films 1
# Universal Pictures|Media Rights Capital|Night Chronicles|Relativity Media 1
# Serendipity Point Films 1
# Icon Productions|BBC Films|GK Films|Warner Bros. 1
# Summit Entertainment|Robert Simonds Productions|Participant Media|Imagenation Abu Dhabi FZ|Furry Vengeance Productions 1
# Hyde Park Films|platinum studios|Long Distance Films 1
# HighRoad Entertainment|Prelude Pictures|Lone Runner Entertainment|Kenio Films|Perfect Game, The 1
# Boram Entertainment Inc. 1
# Ealing Studios|Fragile Films|Quickfire Films|Prescience|Aegis Film Fund 1
# Lions Gate Films|The Tyler Perry Company 1
# Impact Pictures|Davis-Films|Constantin Film Produktion 1
# PVR Cinemas|Hari Om Entertainment Co.|Blockbuster Movie Entertainers 1
# Walt Disney Pictures|Fast Track Productions|Mayhem Pictures 1
# 1492 Pictures|Warner Bros.|Heyday Films 1
# Asymmetrical Productions|Les Films Alain Sarde|Babbo Inc.|The Picture Factory|Canal+ 1
# DreamWorks SKG|Amblin Entertainment|Stanley Kubrick Productions|Warner Bros. 1
# Miramax Films|Universal Pictures|Studio Canal|Working Title Films|Little Bird 1
# Village Roadshow Pictures|Section Eight|NPV Entertainment|Jerry Weintraub Productions|Warner Bros. 1
# Universal Pictures|Alphaville Films|Imhotep Productions 1
# Imagine Entertainment|DreamWorks SKG|Universal Pictures 1
# Universal Pictures|Liveplanet|Zide-Perry Productions 1
# Walt Disney Pictures|BrownHouse Productions|Bottom of the Ninth Productions 1
# Bazmark Films|Twentieth Century Fox Film Corporation 1
# Twentieth Century Fox Film Corporation|Tim Burton Productions|Zanuck Company, The 1
# Paramount Pictures|Swanford Films|Mandalay Pictures|Little Bird|KC Medien 1
# Jerry Bruckheimer Films|Revolution Studios|Scott Free Productions 1
# Marc Platt Productions|Metro-Goldwyn-Mayer (MGM) 1
# Columbia Pictures Corporation|Escape Artists|Black and Blu Entertainment|Finestkind 1
# Paramount Pictures|Village Roadshow Pictures|NPV Entertainment|Scott Rudin Productions|Red Hour Productions 1
# Original Film|Columbia Pictures Corporation|Neal H. Moritz Productions 1
# Village Roadshow Pictures|NPV Entertainment|Warner Bros.|Outlaw Productions (I)|WV Films II 1
# Cruise/Wagner Productions|Canal Plus|Sogecine|Las Producciones del Escorpion|Lucky Red 1
# Nickelodeon Movies|Universal Cartoon Studios|Paramount Animation 1
# Dimension Films|View Askew Productions|Miramax 1
# Miramax Films|Tapestry Films|Simon Fields Productions 1
# Village Roadshow Pictures|NPV Entertainment|Mad Chance|Zide-Perry Productions|Warner Bros. 1
# Paramount Pictures|Cruise-Wagner Productions|Vinyl Films 1
# Twentieth Century Fox Film Corporation|Current Entertainment|Immortal Entertainment|Canal+|EuropaCorp 1
# Universal Pictures|Metropolitan Filmexport|Toho-Towa|Red Wagon Productions|Beacon Communications 1
# Village Roadshow Pictures|NPV Entertainment|Silver Pictures|Warner Bros.|Jonathan Krane Group 1
# Industry Entertainment|Epsilon Motion Pictures|Hyde Park Films|Metro-Goldwyn-Mayer (MGM) 1
# Columbia Pictures|Square USA|Chris Lee Productions 1
# United Artists|American Zoetrope|Cinerenta Medienbeteiligungs KG|Cinerenta-Cinebeta|VCL Communications 1
# Twentieth Century Fox Film Corporation|Underworld Entertainment 1
# DreamWorks SKG 1
# Paramount Pictures|AZL Productions KG|David Brown Productions|MFP Munich Film Partners|Phase 1 Productions 1
# Columbia Pictures Corporation|Intermedia Films|Dee Gee Entertainment|Tapestry Films|Prufrock Pictures 1
# Paramount Pictures|Fireworks Pictures|Alphaville Films 1
# USA Films 1
# New Line Cinema|Sean S. Cunningham Films|Crystal Lake Entertainment 1
# DreamWorks SKG|Newmarket Capital Group|Lawrence Bender Productions|Pistolero Productions LLC 1
# Regency Enterprises|Epsilon Motion Pictures|LivePlanet|New Regency Pictures|Bad Robot 1
# Warner Bros. Pictures|Bel Air Entertainment 1
# Intermedia Films|Lawrence Gordon Productions|PathÃ© Pictures International|IMF Internationale Medien und Film GmbH & Co. 3. Produktions KG 1
# 20th Century Fox|Village Roadshow Pictures|NPV Entertainment|Regency Enterprises|Kopelson Entertainment 1
# Bungalow Productions|Silver Lion Films|Vision View Entertainment 1
# Cinerenta Medienbeteiligungs KG|American Entertainment Partners L.P.|David Kirschner Productions 1
# Warner Bros. Pictures|Franchise Pictures|Morgan Creek Productions 1
# Original Film 1
# New Line Cinema|Industry Entertainment|Tribeca Productions|New Redemption Pictures 1
# Paramount Pictures|GHS Productions KG|Munich Film Partners & Company (MFP) GHS Productions|Nides/McCormick Productions 1
# DreamWorks SKG|Columbia Pictures Corporation|Montecito Picture Company, The 1
# Paramount Pictures|Mandalay Pictures|Horseshoe Bay Productions 1
# NPV Entertainment|Warner Bros. 1
# Columbia Pictures|Merlin Films 1
# Universal Pictures|Jersey Films|Native Pictures Productions 1
# Village Roadshow Pictures|Castle Rock Entertainment|NPV Entertainment|Darkwoods Productions 1
# Franchise Pictures|Warner Bros.|Morgan Creek Productions 1
# Screen Gems|Storm King Productions|Animationwerks 1
# Village Roadshow Pictures|NPV Entertainment|Columbia Pictures Corporation 1
# Conundrum Entertainment|Warner Bros. Animation|Warner Bros. 1
# Universal Studios 1
# Universal Pictures|Original Film|Ardustry Entertainment|Mediastream Film GmbH & Co. Productions KG 1
# MTV Films|Cort/Madden Productions 1
# Cheyenne Enterprises|Epsilon Motion Pictures|Empire Pictures|Metro-Goldwyn-Mayer (MGM)|Hyde Park Entertainment 1
# Revolution Studios|Happy Madison Productions 1
# Lawrence Bender Productions 1
# Touchstone Pictures|Ufland 1
# Epsilon Motion Pictures|Franchise Pictures|Trackform Film Productions|Mel's Cite du Cinema 1
# Spyglass Entertainment|Touchstone Pictures 1
# Warner Bros. Pictures|Morgan Creek Productions 1
# Universal Pictures|Scott Free Productions|Metro-Goldwyn-Mayer (MGM)|Dino De Laurentiis Company 1
# Tollin/Robbins Productions|Warner Bros. 1
# Walt Disney Pictures|Karz Entertainment 1
# 20th Century Fox|1492 Pictures 1
# Robert Simonds Productions|Touchstone Pictures 1
# Universal Studios|Amblin Entertainment 1
# Crystal Sky Worldwide|MDP Worldwide|ApolloMedia Distribution|Carousel Picture Company, The|Signature Entertainment 1
# Lions Gate Films|Dan Films|CP Medien AG 1
# DC Comics|Legendary Pictures|Warner Bros.|Syncopy 1
# Twentieth Century Fox Film Corporation|M6 Films|Canal+|TPS Star|Grive Productions 1
# Lucasfilm|Paramount Pictures 1
# Summit Entertainment|Maverick Films|Imprint Entertainment|Goldcrest Pictures|Temple Hill Entertainment 1
# Universal Pictures|Internationale Filmproduktion Richter|Playtone|Relativity Media|Littlestar 1
# Paramount Pictures|Warner Bros.|Kennedy/Marshall Company, The 1
# Universal Pictures|China Film Co-Production Corporation|Relativity Media|Alphaville Films|Sommers Company, The 1
# Universal Pictures|Marvel Studios|Valhalla Motion Pictures|MVL Incredible Productions 1
# Village Roadshow Pictures|Malpaso Productions|Gerber Pictures|Warner Bros.|Double Nickel Entertainment 1
# Universal Pictures|Dark Horse Entertainment|Lawrence Gordon Productions|Mid Atlantic Films|Relativity Media 1
# Dune Entertainment|Hypnotic|New Regency Pictures 1
# New Line Cinema|Walden Media 1
# Universal Pictures|Spyglass Entertainment|Bazelevs Production|Kickstart Productions|Marc Platt Productions 1
# Celador Films|Warner Bros.|Film4 1
# Europa Corp|TF1 Films Production|Grive Productions|EuropaCorp 1
# United Artists|Achte Babelsberg Film|Metro-Goldwyn-Mayer (MGM)|Bad Hat Harry Productions 1
# Centropolis Entertainment|Legendary Pictures|Warner Bros.|Moonlighting Films|The Department of Trade and Industry of South Africa 1
# Columbia Pictures|Weed Road Pictures|Forward Pass|Relativity Media|Overbrook Entertainment 1
# Summit Entertainment|Kingsgate Films|Grosvenor Park Media Ltd.|Voltage Pictures|Film Capital Europe Funds (FCEF ) 1
# Twentieth Century Fox Film Corporation|Regency Enterprises|Mosaic Media Group|21 Laps Entertainment|Penn Station Entertainment 1
# Walt Disney|Walden Media|Stillking Films|Ozumi Films|Propeler 1
# DreamWorks SKG|Goldcrest Pictures|Red Hour Films|Internationale Filmproduktion Stella-del-Sud Second 1
# DreamWorks SKG|K/O Paper Products|Goldcrest Pictures|KMP Film Invest 1
# Miramax Films|BBC Films|Heyday Films 1
# Rogue Marble|Nu Image Films|Lionsgate|Millennium Films|Emmett/Furla Films 1
# Universal Pictures|Cruise/Wagner Productions|Impact Pictures|Relativity Media|Scion Films 1
# Summit Entertainment|Offspring Entertainment|Touchstone Pictures 1
# Twentieth Century Fox Film Corporation|Dune Entertainment III|Earth Canada Productions|Hammerhead Productions|3 Arts Entertainment 1
# Columbia Pictures|Escape Artists|Relativity Media|Overbrook Entertainment 1
# Paramount Pictures|Bad Robot 1
# Bazmark Films|Ingenious Film Partners|Twentieth Century Fox Film Corporation|Dune Entertainment III|ScreenWest 1
# The Zanuck Company|Heyday films|Warner Bros. 1
# Sunswept Entertainment|Dune Entertainment III 1
# Scott Free Productions|De Line Pictures|Warner Bros. 1
# Spyglass Entertainment|Fox 2000 Pictures|Dune Entertainment III 1
# New Line Cinema|Internationale Filmproduktion Blackbird Erste 1
# Columbia Pictures|Relativity Media 1
# Columbia Pictures|Mosaic Media Group|Gary Sanchez Productions|Relativity Media|Apatow Productions 1
# De Line Pictures|Warner Bros. 1
# Summit Entertainment|Mandalay Pictures|Baumgarten Management and Productions (BMP) 1
# Saturn Films|Wild Bunch|Protozoa Pictures|Top Rope 1
# Walt Disney Pictures|Happy Madison Productions|Gunn Films 1
# Lionsgate|MHF Zweite Academy Film|Marvel Knights|Valhalla Motion Pictures|SGF Entertainment 1
# Dune Entertainment|Firm Films|Collision Entertainment|Abandon Entertainment|Foxtor Productions 1
# Regency Enterprises|Castel Film Romania|ASAF|New Regency Pictures|Luna Pictures 1
# Columbia Pictures|Original Film|Kanzaman|Relativity Media|Art In Motion 1
# Blue Askew|View Askew Productions 1
# Village Roadshow Pictures|Atlas Entertainment|Mosaic Media Group|Mad Chance|Warner Bros. 1
# Universal Pictures|Internationale Filmproduktion Stella-del-SÃ¼d|Relativity Media|New Regency Pictures|WideAwake 1
# StudioCanal|M6 Films|Canal+|CinÃ©CinÃ©ma|Babylon 1
# Blueprint Pictures|Scion Films|Film4|Focus Features|Twins Financing 1
# Imagine Entertainment|Malpaso Productions|Relativity Media 1
# Paramount Pictures|The Kennedy/Marshall Company 1
# Fox Searchlight Pictures|Regency Enterprises|Dune Entertainment III|Emmett/Furla Films 1
# Columbia Pictures|Mandate Pictures|Depth of Field|Screen Gems 1
# New Line Cinema|Spyglass Entertainment|Type A Films|Ott Medien|Wild West Picture Show Productions 1
# Columbia Pictures|Happy Madison Productions|Relativity Media|Alta Loma Entertainment 1
# Paramount Pictures|Goldcrest Pictures|Internationale Filmproduktion 1
# Village Roadshow Pictures|Studio Babelsberg|Anarchos Productions|Silver Pictures|Warner Bros. 1
# The Weinstein Company|Gravier Productions|Antena 3 Films|TelevisiÃ³ de Catalunya (TV3)|Antena 3 TelevisiÃ³n 1
# Casey Silver Productions|China Film Co-Production Corporation|Huayi Brothers|Relativity Media 1
# Grosvenor Park Media Ltd.|InVenture Entertainment|Millennium Films|Emmett/Furla Films|Nu-Image Films 1
# Lietuvos Kinostudija|Scout Productions|Telecinco Cinema|Castelao Producciones|Canal+ EspaÃ±a 1
# Columbia Pictures|Happy Madison Productions|Sony Pictures Releasing 1
# Paramount Vantage|Grosvenor Park Productions|Bedford Falls Company, The|Defiance Productions|Pistachio Pictures 1
# Lakeshore Entertainment|Cohen/Pearl Productions|Screen Gems 1
# Rogue Pictures|Vertigo Entertainment 1
# Ascendant Pictures|Rising Star|VIP Medienfonds 4|Virtual Films|Outlander Productions 1
# Twentieth Century Fox Film Corporation|Ten Thirteen Productions|Dune Entertainment III|Crying Box Productions 1
# Playtone|Walden Media 1
# Columbia Pictures|Original Film 1
# Rifkin-Eberts|Dune Entertainment III|Seed Productions 1
# StudioCanal|Dark Castle Entertainment|Toff Guy Films|Warner Bros. 1
# Paramount Vantage|VN Productions 1
# Virtual Studios|Initial Entertainment Group|Saturn Films|International Production Company|Blue Star Pictures 1
# Regency Enterprises|New Regency Pictures 1
# DC Comics|Lionsgate|Odd Lot Entertainment|Media Magik Entertainment|Dark Lot Entertainment 1
# Spyglass Entertainment|Twentieth Century Fox Film Corporation|Dune Entertainment|UTV Motion Pictures|Blinding Edge Pictures 1
# Rogue Pictures|Intrepid Pictures|Scion Films|Moonlighting Films|Internationale Filmproduktion Blackbird Dritte 1
# South Pacific Pictures|Metropolitan Filmexport|Spice Factory|UK Film Council|The Australian Film Commission 1
# New Line Cinema|Darren Star Productions|Home Box Office (HBO) 1
# Fox Atomic 1
# Universal Pictures Corporation 1
# DreamWorks SKG|Scott Rudin Productions|BBC Films|Neal Street Productions|Evamere Entertainment 1
# Relativity Media|Michaels-Goldwyn 1
# BBC Films|Ecosse Films|HanWay Films|UK Film Council|2 Entertain 1
# The Weinstein Company|Summit Entertainment|Endgame Entertainment 1
# 20th Century Fox|Regency Enterprises|Guy Walks into a Bar Productions|Deep River Productions 1
# Vertigo Entertainment|Screen Gems|Andale Pictures 1
# Davis Entertainment|Relativity Media|IDEA Filmproduktions 1
# Starz Media|Starz Animation|Odyssey Entertainment|Studiopolis|Vanguard Animation 1
# Screen Gems|Overbrook Entertainment 1
# 2929 Productions|Linson Entertainment|Art Linson Productions|Tribeca Productions 1
# Grosvenor Park Media Ltd.|LionsGate|3 in the Box 1
# Lionsgate|New Wave Entertainment|Management 360|Terra Firma Films|Superfinger Entertainment 1
# Lions Gate Films|Lakeshore Entertainment|GreeneStreet Films|Midnight Picture Show 1
# Isle of Man Film|Edward R. Pressman Film|Paradox Entertainment|First Foot Films 1
# Ixtlan Productions|Emperor Motion Pictures|Global Entertainment Group 1
# Miramax Films|Sherazade Film Development|Groundswell Productions|QED International|Corduroy Films 1
# Walden Media 1
# Exodus Film Group|Exodus Productions 1
# UK Film Council|Intandem Films|Aramid Entertainment Fund|Film4|Lipsync Productions 1
# Universal Pictures|Spyglass Entertainment 1
# Bold Films|Marc Platt Productions|Odd Lot Entertainment|FilmDistrict|Motel Movies 1
# Warner Bros.|Heyday Films|Moving Picture Company (MPC) 1
# Walt Disney Pictures|Jerry Bruckheimer Films|Moving Picture Company (MPC) 1
# Marvel Studios|Marvel Entertainment 1
# Regency Enterprises|Strike Entertainment|New Regency Pictures 1
# Summit Entertainment|Saturn Films|Nu Image Films|Millennium Films|Michael De Luca Productions 1
# CBS Films|Millennium Films|Chartoff-Winkler Productions|Scared Productions|Nu Image Entertainment GmbH 1
# The Mark Gordon Company|Vendome Pictures 1
# Paramount Pictures|Skydance Productions|Bad Robot|TC Productions|Revolution Sun Studios 1
# Columbia Pictures|Scott Rudin Productions|Film Rites|Metro-Goldwyn-Mayer (MGM)|Yellow Bird 1
# Rogue Pictures|Relativity Media|Virgin Produced|Many Rivers Productions|Boy of the Year 1
# New Line Cinema|Rat Entertainment 1
# DreamWorks SKG|21 Laps Entertainment|Reliance Entertainment|Touchstone Pictures|ImageMovers 1
# Castle Rock Entertainment|Screen Gems|Olive Bridge Entertainment 1
# Columbia Pictures|Mosaic Media Group 1
# Village Roadshow Pictures|Silver Pictures|Lin Pictures|Warner Bros.|Wigram Productions 1
# De Line Pictures|Warner Bros.|DC Entertainment 1
# Legendary Pictures|Living Films|Green Hat Films|Warner Bros. 1
# Paramount Pictures|Spyglass Entertainment|Katalyst Films|Cold Spring Pictures|Montecito Picture Company, The 1
# Paramount Pictures|Columbia Pictures|WingNut Films|Amblin Entertainment|Nickelodeon Movies 1
# Universal Pictures|Relativity Media|Apatow Productions 1
# New Line Cinema|Conundrum Entertainment 1
# Paramount Pictures|Amblin Entertainment|Bad Robot|K/O Camera Toys 1
# Legendary Pictures|Warner Bros.|Lennox House Films|Cruel and Unusual Films 1
# Appian Way|Warner Bros.|Random Films 1
# Summit Entertainment|Sunswept Entertainment|Total Entertainment|TSBD Canada Productions|Zohar International 1
# DreamWorks SKG|Reliance BIG Entertainment|Bay Films|Touchstone Pictures 1
# France 3 CinÃ©ma|La Petite Reine|Studio 37|uFilm|Jouror Productions 1
# Columbia Pictures|Happy Madison Productions|Sony Pictures Releasing|Broken Road Productions|Metro-Goldwyn-Mayer (MGM) 1
# Imagine Entertainment|DreamWorks SKG|Universal Pictures|platinum studios|Reliance Entertainment 1
# DreamWorks SKG|Amblin Entertainment|Reliance Entertainment|Kennedy/Marshall Company, The 1
# Summit Entertainment|Mandate Pictures 1
# Paramount Pictures|Nickelodeon Movies|GK Films|Blind Wink|Paramount Animation 1
# Universal Pictures|Original Film|Relativity Media|Big Kid Pictures 1
# Paramount Pictures|Infinitum Nihil|GK Films 1
# Lakeshore Entertainment|Sidney Kimmel Entertainment|Lionsgate 1
# Columbia Pictures|Imagenation Abu Dhabi FZ|Marvel Entertainment|Marvel Knights|Hyde Park Entertainment 1
# Film 4|Color Force 1
# Current Entertainment|Omnilab Media|Ambience Entertainment|International Traders|Open Road Films 1
# New Line Cinema|Contrafilm|Mid Atlantic Films|Hungarian National Film Office|Lazio Film Commission 1
# Impact Pictures|Studio Babelsberg|Nouvelles Ã‰ditions de Films (NEF)|New Legacy|Constantin Film Produktion 1
# Screen Gems|Stars Road Entertainment|Buckaroo Entertainment|Michael De Luca Productions|TOKYOPOP 1
# Paramount Pictures|Denver and Delilah Productions|Indian Paintbrush 1
# Lions Gate Films|Vertigo Entertainment|Gotham Group|Tailor Made|Mango Farms 1
# Studio Babelsberg|StudioCanal|Dark Castle Entertainment|TF1 Films Production|Canal+ 1
# Universal Pictures|Media Rights Capital|Gambit Pictures|Electric Shepherd Productions 1
# Virgin Produced|Mark Canton Productions 1
# Universal Pictures|Playtone Productions|Vendome Pictures 1
# Universal Pictures|Big Talk Productions|Relativity Media|Working Title Films 1
# TF1 Films Production|Canal+|CinÃ©CinÃ©ma|Grive Productions|EuropaCorp 1
# Columbia Pictures|Original Film|Relativity Media 1
# Mpower Pictures|Relativity Media|1984 Private Defense Contractors|Virgin Produced|Moonlighting Films 1
# Columbia Pictures|Happy Madison Productions|Broken Road Productions 1
# Regency Enterprises|Contrafilm|New Regency Pictures 1
# Atlas Entertainment|Relativity Media 1
# BBC Films|The Weinstein Company|UK Film Council|Lip Sync Post|Trademark Films 1
# Twentieth Century Fox Film Corporation|Dune Entertainment|Vinyl Films|LBI Entertainment 1
# Summit Entertainment|Regency Enterprises|Bazelevs Production|The Jacobson Company|New Regency Pictures 1
# DreamWorks SKG|1492 Pictures|Participant Productions|Imagenation Abu Dhabi FZ|Reliance Entertainment 1
# Scott Free Productions|1984 Private Defense Contractors|LD Entertainment|Open Road Films|Inferno Distribution 1
# Columbia Pictures|Scott Rudin Productions 1
# Vertigo Entertainment|Screen Gems 1
# Original Film|Sony Pictures Entertainment|Reliance BIG Entertainment 1
# Alcon Entertainment|Wild Ocean Films|2S Films 1
# ...
# Virtual Studios|Legendary Pictures|Hollywood Gang Productions|Atmosphere Entertainment MM|Warner Bros. 1
# Columbia Pictures Corporation|Relativity Media|Michael De Luca Productions|Marvel Enterprises|Crystal Sky Pictures 1
# Fox Searchlight Pictures|Mandate Pictures 1
# Walden Media|Hal Lieberman Company|Lauren Levine Productions Inc. 1
# Paramount Pictures|Di Bonaventura Pictures|Grosvenor Park Impact Productions 1
# Universal Pictures|Studio Canal|Relativity Media|Working Title Films 1
# Miramax Films|Ghoulardi Film Company|Paramount Vantage 1
# Imagine Entertainment|Universal Pictures|Scott Free Productions|Relativity Media|Film Rites 1
# Warner Bros.|DreamWorks Pictures|Tim Burton Productions|Zanuck Company, The|Parkes+MacDonald Image Nation 1
# Dune Entertainment|Regency Enterprises|Fox 2000 Pictures|Bagdasarian Productions 1
# Pacific Data Images (PDI)|DreamWorks Animation|Columbus 81 Productions 1
# Wendy Finerman Productions|Alcon Entertainment|Grosvenor Park Productions 1
# New Line Cinema|Contrafilm|Firm Films 1
# Ingenious Film Partners|Twentieth Century Fox Film Corporation|1492 Pictures|Dune Entertainment|Constantin Film Produktion 1
# Walt Disney Pictures|Josephson Entertainment|Andalasia Productions|Right Coast Productions 1
# Paramount Pictures|Warner Bros.|Phoenix Pictures 1
# Village Roadshow Pictures|Section Eight|Jerry Weintraub Productions|Warner Bros. 1
# The Weinstein Company|Imagi Animation Studios|Warner Bros.|Mirage Studios|Imagi Production 1
# Gracie Films|Twentieth Century Fox Film Corporation 1
# Universal Pictures|Participant Productions|Playtone Production 1
# DNA Films|Figment Films|Sociedad General de Cine S.A.|UK Film Council|Fox Atomic 1
# Universal Pictures|Forward Pass|Relativity Media|FilmWorks|MDBF Zweite Filmgesellschaft 1
# DNA Films|Ingenious Film Partners|UK Film Council|Moving Picture Company (MPC) 1
# Tiger Aspect Productions|Working Title Films 1
# Tig Productions|Eden Rock Media|Element Films|Relativity Media 1
# Columbia Pictures|Dark Horse Entertainment|Ghost House Pictures|HorrorFlix 1
# New Line Cinema|Ingenious Film Partners|Depth of Field|Scholastic Productions 1
# TriStar Pictures|Nu Image Entertainment|Brightlight Pictures 1
# Paramount Pictures|DreamWorks SKG|Cold Spring Pictures|Montecito Picture Company, The 1
# Cruise/Wagner Productions|United Artists|Wildwood Enterprises|Andell Entertainment|Metro-Goldwyn-Mayer (MGM) 1
# Tree Line Films|Lionsgate|Relativity Media|Yuma 1
# Warner Bros.|CJ Entertainment|Southpaw Entertainment 1
# The Weinstein Company|Open City Films|GreeneStreet Films 1
# Mosaic Media Group|Current Entertainment|Lionsgate|Fierce Entertainment|Province of British Columbia Production Services Tax Credit 1
# Columbia Pictures|Universal Pictures|Spyglass Entertainment|Shady Acres Entertainment|Original Film 1
# Universal Pictures|Happy Madison Productions 1
# Paramount Pictures|Virtual Studios|Revolution Studios|Saturn Films|Broken Road Productions 1
# TriStar Pictures|Hyde Park Films|Offspring Entertainment 1
# Lions Gate Films|Twisted Pictures 1
# Silver Pictures|Warner Bros.|Jessie Nelson Productions|David Dobkin Productions 1
# New Line Cinema|Angry Films 1
# BBC Films|Serendipity Point Films|TÃ©lÃ©film Canada|Astral Media|Scion Films 1
# Paramount Pictures|Shangri-La Entertainment|ImageMovers|Paramount Animation 1
# Village Roadshow Pictures|Castle Rock Entertainment|Warner Bros.|Storefront Pictures|WV Films III 1
# Conundrum Entertainment|Davis Entertainment|DreamWorks Pictures|Radar Pictures 1
# Twentieth Century Fox Film Corporation|Dune Entertainment|Anka Film|EuropaCorp|Daybreak Productions 1
# Walt Disney Pictures|Mayhem Pictures|Monkey Dance Productions 1
# Big Talk Productions|Yer Dead Productions|Weinstein Company, The|Dimension Films|Troublemaker Studios 1
# Entertainment Films|Material Entertainment|Beech Hill Films 1
# Warner Bros.|Storyline Entertainment|Two Ton Films|Zadan / Meron Productions 1
# Lions Gate Films|Next Entertainment|Screen Gems 1
# Intrepid Pictures|Focus Films|Platinum Dunes 1
# TriStar Pictures|360 Pictures 1
# Dimension Films|Spectacle Entertainment Group|Nightfall Productions 1
# Ecosse Films|2 Entertain|Bueprint Pictures 1
# Halcyon Pictures|Kinematograf Wien 1
# Universal Pictures|StudioCanal|Working Title Films 1
# Village Roadshow Pictures|Vertigo Entertainment|Silver Pictures|Warner Bros. 1
# Capitol Films|Linsefilm|Unity Productions|Michael Cerenzie Productions|Funky Buddha Productions 1
# Revolution Studios|TriStar Pictures 1
# Impact Pictures|Davis-Films|Constantin Film Produktion|Resident Evil Productions 1
# Plan B Entertainment|Virtual Studios|Scott Free Productions|Alberta Film Entertainment|Warner Bros. 1
# Plan B Entertainment|Revolution Films|Paramount Vantage 1
# Village Roadshow Pictures|Dark Castle Entertainment|Warner Bros.|Eyetronics|Chime Films 1
# DreamWorks SKG|Davis Entertainment|Tollin/Robbins Productions 1
# Village Roadshow Pictures|Castle Rock Entertainment|Reserve Room|Flower Films (II) 1
# Anonymous Content|Level 1 Entertainment|MID Foundation 1
# Summit Entertainment|Blackfriars Bridge Films|NALA Films|Samuels Media|Warner Independent Pictures (WIP) 1
# Lionsgate|Karz Entertainment 1
# Twentieth Century Fox Film Corporation|Regency Enterprises|New Regency Pictures|Paul Schiff Productions 1
# Castle Rock Entertainment|Land Films Inc.|Anonymous Content 1
# The Weinstein Company|FilmColony 1
# The Weinstein Company|Harpo Films|Marshall Production 1
# Double Feature Films|Jersey Films|Kernos Filmproduktionsgesellschaft & Company 1
# Spyglass Entertainment|Hollywood Pictures|Birnbaum / Barber Productions 1
# Columbia Pictures|Industry Entertainment|2929 Productions 1
# DreamWorks SKG|MacDonald/Parkes Productions|Sidney Kimmel Entertainment|Neal Street Productions|China Film Co-Production Corporation 1
# Screen Gems|Hal Lieberman Company 1
# Touchstone Pictures|Focus Features|Jon Shestack Productions 1
# Morgan Creek Productions|Clifford Werber Productions|SW7D Productions 1
# Foresight Unlimited|RAMCO|Captivity Productions 1
# Village Roadshow Pictures|Warner Bros. Pictures|Robert Simonds Productions|Phoenix Pictures|Underground 1
# Scott Rudin Productions|I Could Never Ltd.|Bauer Martinez Studios 1
# Castle Rock Entertainment|Mirage Enterprises|Section Eight Productions 1
# Revolution Studios|Ecosse Films|Beacon Pictures|Walden Media 1
# Twentieth Century Fox Film Corporation|Dune Entertainment|Baldwin Entertainment Group|Hyde Park Entertainment|Brass Hat Films 1
# Twentieth Century Fox Film Corporation|Dune Entertainment|Major Studio Partners|Phoenix Pictures 1
# Miramax Films|The Ladd Company 1
# Columbia Pictures Corporation|Apatow Productions 1
# DreamWorks SKG|Neal Street Productions|DreamWorks Pictures|Province of British Columbia Production Services Tax Credit 1
# Columbia Pictures|Happy Madison Productions|Sunlight Productions|Relativity Media|Madison 23 1
# New Line Cinema|Grosvenor Park Media Ltd. 1
# Endgame Entertainment|Rising Star|Killer Films|John Wells Productions|Dreamachine 1
# BBC 1
# Ingenious Film Partners|Quinta Communications|Dino De Laurentiis Company|Zephyr Films 1
# Universal Pictures|Canadian Film or Video Production Tax Credit (CPTC)|Gold Circle Films|Province of British Columbia Production Services Tax Credit|H2F Entertainment 1
# Block 2 Pictures|Jet Tone Production|StudioCanal|Lou Yi Inc. 1
# Ingenious Film Partners|Dino de Laurentiis Cinematografica|Dino De Laurentiis Company|Zephyr Films|Red Lion Sarl 1
# Universal Pictures|Twisted Pictures|Evolution Entertainment 1
# Ingenious Film Partners|ETIC Films|Quinta Communications|Dino De Laurentiis Company|Zephyr Films 1
# Huayi Brothers Media Corporation 1
# Lions Gate Films|Tyler Perry Company, The 1
# DreamWorks SKG|Universal Pictures|Scott Free Productions|Red Wagon Entertainment|Mill Film 1
# Summit Entertainment|Newmarket Capital Group|Team Todd|I Remember Productions 1
# DreamWorks SKG|Twentieth Century Fox Film Corporation|Playtone|ImageMovers 1
# Columbia Pictures Corporation|SKA Films 1
# Paramount Pictures|Cruise/Wagner Productions|Munich Film Partners & Company (MFP) MI2 Productions 1
# Twentieth Century Fox Film Corporation|Regency Enterprises|KirchMedia 1
# Paramount Pictures|Centropolis Entertainment|Icon Entertainment International|Wind Dancer Productions 1
# DreamWorks SKG|Aardman Animations|DreamWorks Animation|PathÃ© 1
# Centropolis Entertainment|Columbia Pictures Corporation|Mutual Film Company|Global Entertainment Productions GmbH & Company Medien KG 1
# New Line Cinema|Zide-Perry Productions|Hard Eight Pictures 1
# Universal Pictures|Canal Plus|Dino De Laurentiis Company 1
# BBC Films|Tiger Aspect Productions|StudioCanal|Arts Council of England|Working Title Films 1
# Jersey Films 1
# DreamWorks SKG|Universal Pictures|Tribeca Productions|Nancy Tenenbaum Films 1
# Universal Pictures|Studio Canal|Touchstone Pictures 1
# Interscope Communications|Polygram Filmed Entertainment 1
# Village Roadshow Pictures|Castle Rock Entertainment|NPV Entertainment|Fortis Films|Warner Bros. 1
# Twentieth Century Fox Film Corporation|Regency Enterprises 1
# Lions Gate Films|Edward R. Pressman Film|Muse Productions 1
# Fine Line Features|Zentropa Entertainments|Danmarks Radio (DR)|SVT Drama|Arte 1
# Walt Disney Pictures|Jerry Bruckheimer Films|Technical Black|Run It Up Productions Inc. 1
# DreamWorks SKG|Twentieth Century Fox Film Corporation|Wildwood Enterprises|Epsilon Motion Pictures|Allied Filmmakers 1
# USA Films|Initial Entertainment Group (IEG)|Bedford Falls Company, The|Compulsion Inc.|Splendid Medien AG 1
# Twentieth Century Fox Film Corporation|Alcon Entertainment 1
# Columbia Pictures|Phoenix Pictures 1
# Universal Pictures|Original Film|Newmarket Capital Group|Cranium Films 1
# Limited Edition Productions Inc.|Touchstone Pictures|Blinding Edge Pictures|Barry Mendel Productions 1
# Village Roadshow Pictures|Malpaso Productions|Mad Chance|Warner Bros.|Clipsal Films 1
# Franchise Pictures|Warner Bros.|Morgan Creek Productions|Nine Yards Productions|Rational Packaging Company 1
# Columbia Pictures|Vinyl Films|DreamWorks Pictures 1
# Beacon Communications 1
# Miramax Films|David Brown Productions|Fat Free 1
# Buena Vista|Touchstone Pictures 1
# Village Roadshow Pictures|NPV Entertainment|Warner Bros.|The Canton Company|Mars Production Pty. Ltd. 1
# Spyglass Entertainment|The Jacobson Company|Touchstone Pictures|Red Horizon Productions 1
# New Line Cinema|Avery Pix|Radical Media|Katira Productions GmbH & Co. KG|Caro-McLeod 1
# Franchise Pictures|Warner Bros.|Morgan Creek Productions|The Canton Company 1
# Universal Pictures|Amblin Entertainment 1
# New Line Cinema|Tig Productions 1
# 20th Century Fox|Figment Films 1
# Warner Bros.|Baltimore Spring Creek Productions|Radiant Productions 1
# Twentieth Century Fox Film Corporation|David Kirschner Productions|Fox Animation Studios 1
# Konrad Pictures|Craven-Maddalena Films|Dimension Films 1
# Dimension Films|Marty Katz Productions 1
# Neo Art & Logic|Dimension Films|Wes Craven Films 1
# DreamWorks SKG|Twentieth Century Fox Film Corporation|ImageMovers 1
# Paramount Pictures|Seven Arts Pictures|Munich Film Partners & Company (MFP) ROE Production 1
# Fountainbridge Films|Laurence Mark Productions|Columbia Pictures Corporation|Finding Forrester Productions 1
# Walt Disney Pictures|Cruella Productions 1
# Spyglass Entertainment|Touchstone Pictures|Triple Threat Talent 1
# United Artists|Metro-Goldwyn-Mayer (MGM)|Hammerhead Productions|Screenland Pictures 1
# Amen Ra Films|Franchise Pictures|Warner Bros.|Morgan Creek Productions 1
# Davis-Panzer Productions|Dimension Films 1
# 40 Acres & A Mule Filmworks 1
# Fox Searchlight Pictures|Industry Entertainment|Walrus & Associates|Hollywood Partners|Charenton Productions 1
# New Line Cinema|Silver Pictures|Sweetpea Entertainment 1
# SNL Studios 1
# Metro-Goldwyn-Mayer (MGM)|JLT Productions 1
# Twentieth Century Fox Film Corporation|Donners' Company|Bad Hat Harry Productions|Marvel Enterprises|Springwood Productions 1
# Universal Pictures|Capella International|KC Medien AG|Tribeca Productions 1
# Laurence Mark Productions|Columbia Pictures Corporation|Global Entertainment Productions GmbH & Company Medien KG|Nora Ephron Productions 1
# Universal Pictures|Media Rights Capital|Fuzzy Door Productions 2
# EuropaCorp 2
# Legendary Pictures 2
# Sony Pictures 2
# Working Title Films 2
# Treehouse Pictures 2
# Walt Disney Pictures|Roth Films 2
# Sony Pictures|Screen Gems 2
# Millennium Films 2
# Warner Bros.|Heyday Films 2
# Summit Entertainment|Maverick Films|Imprint Entertainment|Sunswept Entertainment|Temple Hill Entertainment 2
# Focus Features|Laika Entertainment 2
# New Line Cinema|Offspring Entertainment 2
# New Line Cinema|Practical Pictures|Parallel Zide 2
# Lionsgate|Twisted Pictures 2
# Mike Zoss Productions|Studio Canal|Relativity Media|Focus Features|Working Title Films 2
# Paramount Pictures|DreamWorks SKG|Amblin Entertainment|Di Bonaventura Pictures|Platinum Dunes 2
# BBC Films 2
# Walt Disney Pictures|Jerry Bruckheimer Films 2
# 20th Century Fox|Regency Enterprises 2
# Rainforest Films 2
# WingNut Films|New Line Cinema|The Saul Zaentz Company 2
# Paramount Pictures|Toho-Towa|Mutual Film Company|Lawrence Gordon Productions|British Broadcasting Corporation (BBC) 2
# Gold/Miller Productions|Wayans Bros. Entertainment|Dimension Films|Brad Grey Pictures 2
# Twentieth Century Fox Film Corporation|Davis Entertainment 2
# Castle Rock Entertainment 2
# Columbia Pictures Corporation 2
# Dimension Films|Troublemaker Studios|Miramax 2
# Twentieth Century Fox Film Corporation|Blue Sky Studios|Twentieth Century Fox Animation 2
# Focus Features 2
# Fox Searchlight Pictures 2
# Fox Searchlight 2
# Walt Disney Animation Studios 2
# Paramount Pictures|Blumhouse Productions|Room 101|Solana Films 2
# Lucasfilm 2
# WingNut Films|New Line Cinema|Metro-Goldwyn-Mayer (MGM) 2
# Nu Image Films|Millennium Films 2
# Apatow Productions 2
# DreamWorks SKG|Touchstone Pictures 2
# Miramax Films|A Band Apart|Super Cool ManChu 2
# Twentieth Century Fox Film Corporation|Regency Enterprises|Epsilon Motion Pictures|New Regency Pictures|Marvel Enterprises 2
# DreamWorks SKG|The Montecito Picture Company 2
# Silver Pictures|Warner Bros. 2
# Lakeshore Entertainment|Alphaville Films 2
# Regency Enterprises|Epsilon Motion Pictures|New Regency Pictures 2
# Splendid Pictures|Maverick Films|Metro-Goldwyn-Mayer (MGM)|Dylan Sellers Productions|Madacy Entertainment 2
# Twentieth Century Fox Film Corporation|Conundrum Entertainment 2
# Lions Gate Films 2
# Paramount Pictures|De Line Pictures 2
# Aardman Animations|DreamWorks Animation 2
# Universal Pictures|Morgan Creek Productions 2
# Imagine Entertainment|Touchstone Pictures 2
# Walt Disney Pictures|Jerry Bruckheimer Films|Second Mate Productions 2
# DreamWorks SKG|Amblin Entertainment|Malpaso Productions|Warner Bros. 2
# Sony Pictures Animation 2
# Paramount Pictures|Nickelodeon Movies|Paramount Animation 2
# Paramount Pictures|Scott Rudin Productions 2
# Columbia Pictures Corporation|Global Entertainment Productions GmbH & Company Medien KG 2
# Columbia Pictures|Happy Madison Productions 3
# Columbia Pictures|Sony Pictures Animation 3
# Screen Gems 3
# Lionsgate|Color Force 3
# Relativity Media 3
# Columbia Pictures|Happy Madison Productions|Relativity Media 3
# DreamWorks 3
# Warner Bros. Pictures 3
# Bel Air Entertainment|Warner Bros. 3
# Columbia Pictures|Revolution Studios 3
# Eon Productions 3
# Universal Pictures|Apatow Productions 3
# Columbia Pictures|Apatow Productions 3
# Summit Entertainment 3
# Imagine Entertainment|Universal Pictures 3
# Jerry Bruckheimer Films|Touchstone Pictures 4
# Lionsgate 4
# DreamWorks SKG|Pacific Data Images (PDI)|DreamWorks Animation 4
# The Weinstein Company 4
# Universal Pictures|Illumination Entertainment 5
# Warner Bros. 5
# Metro-Goldwyn-Mayer (MGM) 5
# Fox 2000 Pictures 6
# Blue Sky Studios|Twentieth Century Fox Animation 6
# Miramax Films 6
# Twentieth Century Fox Film Corporation 6
# Walt Disney Pictures|Walt Disney Feature Animation 7
# Marvel Studios 8
# Walt Disney Pictures|Walt Disney Animation Studios 8
# 20th Century Fox 8
# Touchstone Pictures 8
# Walt Disney Pictures|Pixar Animation Studios 10
# Walt Disney Pictures 11
# Columbia Pictures 12
# Dimension Films 12
# Universal Pictures 13
# DreamWorks Animation 14
# Paramount Pictures 14
# New Line Cinema 21
